# %% [markdown]
# ### BNN regression, example (Housing -dataset)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# pip install torchbnn
import torchbnn as bnn
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, root_mean_squared_error, explained_variance_score
import seaborn as sns

# %%
# Load dataset
# So, we have 20K + rows but we need 3000-4000 rows to implement BNN regression.
df = pd.read_csv("Housing.csv")

df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# As this dataset has lon and lat, I will drop them and create "distance_to_nearest_city" based on coordinates,
# Also, "ocean_proximity" is a categorical variable, so I will one-hot encode it. I did that many times already in previous courses,
# so, i will download modified dataset from Advanced Data Analysis course Project 1 and will use here:

df = pd.read_csv("housing_modified.csv")  
df.describe()
# Out:
#        housing_median_age   total_rooms  total_bedrooms    population  \
# count        20433.000000  20433.000000    20433.000000  20433.000000
# mean            28.633094   2636.504233      537.870553   1424.946949
# std             12.591805   2185.269567      421.385070   1133.208490
# min              1.000000      2.000000        1.000000      3.000000
# 25%             18.000000   1450.000000      296.000000    787.000000
# 50%             29.000000   2127.000000      435.000000   1166.000000
# 75%             37.000000   3143.000000      647.000000   1722.000000
# max             52.000000  39320.000000     6445.000000  35682.000000
#
#          households  median_income  median_house_value  \
# count  20433.000000   20433.000000        20433.000000
# mean     499.433465       3.871162       206864.413155
# std      382.299226       1.899291       115435.667099
# min        1.000000       0.499900        14999.000000
# 25%      280.000000       2.563700       119500.000000
# 50%      409.000000       3.536500       179700.000000
# 75%      604.000000       4.744000       264700.000000
# max     6082.000000      15.000100       500001.000000
#
#        distance_to_nearest_city  ocean_proximity_<1H OCEAN  \
# count              20433.000000               20433.000000
# mean                  89.803481                   0.442128
# std                   84.324286                   0.496652
# min                    0.420000                   0.000000
# 25%                   22.810000                   0.000000
# 50%                   57.990000                   0.000000
# 75%                  140.190000                   1.000000
# max                  489.120000                   1.000000
#
#        ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# count            20433.000000            20433.000000
# mean                 0.317917                0.000245
# std                  0.465678                0.015641
# min                  0.000000                0.000000
# 25%                  0.000000                0.000000
# 50%                  0.000000                0.000000
# 75%                  1.000000                0.000000
# max                  1.000000                1.000000
#
#        ocean_proximity_NEAR BAY
# count              20433.000000
# mean                   0.111095
# std                    0.314257
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.000000
# max                    1.000000

# %%
# Still we have 20K + rows, so I will trim the extreme values of the target 
# and also use quantile for other variables that have skewed distributional.
# I implemented that many times, I will paste here the path to the notebook in Git where i did that. 
# https://github.com/RovSveta/Advanced_Data_analytics_2025/blob/main/Exercise_project_1/Regression_dataset/outlier_and_noise_detection.ipynb
# I will use trimmed hoising dataset from that notebook, which is already preprocessed and ready to use for BNN regression.
df = pd.read_csv("housing_trimmed_variables.csv")  
df.describe()
# Out:
#        housing_median_age   total_rooms    population  median_income  \
# count        18322.000000  18322.000000  18322.000000   18322.000000
# mean            29.083233   2265.231034   1239.759197       3.659993
# std             12.333480   1257.714758    647.909942       1.567422
# min              1.000000      2.000000      3.000000       0.499900
# 25%             19.000000   1402.000000    776.000000       2.515600
# 50%             29.000000   2028.000000   1133.000000       3.430600
# 75%             37.000000   2892.750000   1613.000000       4.562500
# max             52.000000   7474.000000   3199.000000      15.000100
#
#        median_house_value  distance_to_nearest_city  \
# count        18322.000000              18322.000000
# mean        192250.168977                 92.746209
# std          98518.273091                 86.249704
# min          14999.000000                  0.420000
# 25%         114800.000000                 22.982500
# 50%         173400.000000                 60.275000
# 75%         248300.000000                144.557500
# max         500000.000000                489.120000
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# count               18322.000000            18322.000000
# mean                    0.434614                0.329331
# std                     0.495720                0.469983
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# 50%                     0.000000                0.000000
# 75%                     1.000000                1.000000
# max                     1.000000                1.000000
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY
# count            18322.000000              18322.000000
# mean                 0.000273                  0.109377
# std                  0.016518                  0.312120
# min                  0.000000                  0.000000
# 25%                  0.000000                  0.000000
# 50%                  0.000000                  0.000000
# 75%                  0.000000                  0.000000
# max                  1.000000                  1.000000

# %%
# Still too many rows. I will dowsample the dataset to 4000 rows, which is more suitable for BNN regression.
# Downsample to 4000 rows
df = df.sample(n=4000, random_state=42).reset_index(drop=True)
df.describe()
# Out:
#        housing_median_age  total_rooms   population  median_income  \
# count         4000.000000  4000.000000  4000.000000    4000.000000
# mean            29.063750  2264.635000  1246.514750       3.642012
# std             12.363491  1245.908381   655.034797       1.548198
# min              2.000000     2.000000     6.000000       0.499900
# 25%             18.750000  1393.750000   776.750000       2.511975
# 50%             30.000000  2036.000000  1131.000000       3.424150
# 75%             37.000000  2888.500000  1638.250000       4.522650
# max             52.000000  7474.000000  3193.000000      12.329200
#
#        median_house_value  distance_to_nearest_city  \
# count         4000.000000               4000.000000
# mean        191981.624500                 92.336990
# std          98210.229605                 85.968757
# min          14999.000000                  0.570000
# 25%         114975.000000                 22.630000
# 50%         172200.000000                 59.405000
# 75%         247600.000000                141.902500
# max         500000.000000                489.120000
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# count                4000.000000             4000.000000
# mean                    0.432500                0.334500
# std                     0.495485                0.471874
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# 50%                     0.000000                0.000000
# 75%                     1.000000                1.000000
# max                     1.000000                1.000000
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY
# count             4000.000000               4000.000000
# mean                 0.000500                  0.104750
# std                  0.022358                  0.306269
# min                  0.000000                  0.000000
# 25%                  0.000000                  0.000000
# 50%                  0.000000                  0.000000
# 75%                  0.000000                  0.000000
# max                  1.000000                  1.000000

# %%
gdgdgdg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 gdgdgdg
#
# NameError: name 'gdgdgdg' is not defined

# %%
# some tricks to do the usual binary/nominal -category conversions
# however, doesn't work for ordinals, so if those are present, got to convert those separately

# encoding all variables in the dataset
from sklearn.preprocessing import LabelEncoder

# Get the list of all object columns
object_variables = df.select_dtypes(include=['object']).columns.tolist()

# Find all the boolean columns
bool_variables = [col for col in object_variables if df[col].nunique() == 2]

# Find all the categorical columns with more than 2 unique values
cat_variables = [col for col in object_variables if df[col].nunique() > 2]

encoder = LabelEncoder()
df[bool_variables] = df[bool_variables].apply(encoder.fit_transform)

# get dummies for categorical variables
df = pd.get_dummies(df, columns=cat_variables, drop_first=True)
# Out:
# C:\Users\tuomas.valtanen\AppData\Local\Temp\ipykernel_24508\2452743714.py:8: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   object_variables = df.select_dtypes(include=['object']).columns.tolist()

# %%
# Check for nans
df.isnull().sum()
# Out:
# price                              0
# area                               0
# bedrooms                           0
# bathrooms                          0
# stories                            0
# mainroad                           0
# guestroom                          0
# basement                           0
# hotwaterheating                    0
# airconditioning                    0
# parking                            0
# prefarea                           0
# furnishingstatus_semi-furnished    0
# furnishingstatus_unfurnished       0
# dtype: int64

# %% [markdown]
# #### X/y- and train/test/validation -split

# %%
# Split features and target
X = df.drop(columns=['price']).values
y = df['price'].values.reshape(-1, 1)

# Normalize features 
feature_scaler = StandardScaler()
X = feature_scaler.fit_transform(X)

# Normalize target variable
target_scaler = StandardScaler()
y = target_scaler.fit_transform(y)

# First, split the data into train and remaining (validation + test)
X_train, X_remaining, y_train, y_remaining = train_test_split(X, y, test_size=0.3, random_state=42)

# Second, split the remaining data into validation and test sets (e.g., 50% validation, 50% test)
X_val, X_test, y_val, y_test = train_test_split(X_remaining, y_remaining, test_size=0.5, random_state=42)

# Convert to PyTorch tensors
X_train, X_test, X_val = torch.tensor(X_train, dtype=torch.float32), torch.tensor(X_test, dtype=torch.float32), torch.tensor(X_val, dtype=torch.float32)
y_train, y_test, y_val = torch.tensor(y_train, dtype=torch.float32), torch.tensor(y_test, dtype=torch.float32), torch.tensor(y_val, dtype=torch.float32) 

# create PyTorch dataloaders, YOU CAN ADJUST THE BATCH SIZES IF YOU WISH
# basic rule: bigger batch size => faster training, but more memory needed
# only shuffle the training dataset, NEVER SHUFFLE TEST/VAL
train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=64, shuffle=True)
test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=64, shuffle=False)
val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=64, shuffle=False)

# %% [markdown]
# ### Hyperparameters and other configurables for the BNN

# %%
# all common hyperparameters we can finetune in the future

# sigma = standard deviation of the noise term (this is often optimized)
# if model is too confident and OVERFITS at the same time, INCREASE sigma
# if predictions are too noisy, too much variation or uncertain  => DECREASE sigma
# COMMON VALUES 0.1 - 0.5

# lambda_kl = amount of KL in the loss function => regularization parameter to avoid OVERFITTING
# if model overfits => increase, if model underfits => decrease
# COMMON VALUES 0.0+ - 0.2

# mu = mean of distribution (you can usually use the default 0 in classification)
# if model overfits => decrease mu
# if model underfits => increase mu
# mu = 0 => in the middle of standard distribution (range -3 to +3) => this needs be checked!
# COMMON VALUES: usually 0 in classification

# mc_samples_eval = monte carlo sample size used to approximate distributions in weights
# more samples used => more accurate uncertainty estimation (but heavier to compute)
# if uncertainty is not optimal, try increasing mc_sample -size a little bit
# if model training is too heavy or underfits, you can decrease the sample size
# COMMON VALUES: 25 - 200

mu = 0
sigma = 0.4
lambda_kl = 0.1
mc_samples_eval = 50

# remember to adjust the BNN network structure in the below cell if needed
# amount of layers, layer sizes, amount of dropout regularization etc.

# learning rate is same as in ANN => controls the aggressiveness of optimization
# too large value => model overshoots optimization attempts
# too small value => model learns too slowly
# COMMON VALUES similar to ANN learning rates, small values (0.03 or less), usually 0.1 or less
bnn_learning_rate = 0.001

# weight_decay = regularization applied to model weights (probability distributions)
# penalizes large weights IN ORDER to prevent OVERFITTING
# if model overfits => you can try increasing weight decay, if underfits => try decreasing
# COMMON VALUES are usually quite small, 0.0001 to 0.0005
bnn_weight_decay = 0.0001

# %% [markdown]
# ### Define Bayesian Neural Network for PyTorch

# %% [markdown]
# <b>See the ordinal example picture how to connect BNN-layers in PyTorch</b>

# %%
# Bayesian Neural Network -model (BNN) with deeper layers and Monte-Carlo dropout
class BayesianNN(nn.Module):
    def __init__(self, input_dim, output_dim, mu=0, sigma=0.5):
        super().__init__()
        # DEFINE ALL LAYERS THAT WILL BE COMBINED INTO ONE MODEL IN forward()
        # NOTE: Torch requires as to "chain" connected layer => out_features and in_features have to match in connected layers
        # for example "in_features=96, out_features=48" means that previous layers to have out_features of 96
        # and the next layer has to have in features of 48
        self.fc1 = bnn.BayesLinear(prior_mu=mu, prior_sigma=sigma, in_features=input_dim, out_features=128)
        self.fc2 = bnn.BayesLinear(prior_mu=mu, prior_sigma=sigma, in_features=128, out_features=64)
        self.fc3 = bnn.BayesLinear(prior_mu=mu, prior_sigma=sigma, in_features=64, out_features=32)
        self.fc4 = bnn.BayesLinear(prior_mu=mu, prior_sigma=sigma, in_features=32, out_features=16)
        self.fc5 = bnn.BayesLinear(prior_mu=mu, prior_sigma=sigma, in_features=16, out_features=output_dim)
        self.relu = nn.ReLU()

        # adjust dropout rate to increase regularization
        self.dropout = nn.Dropout(0.3)  

        # THE BATCH NORMALIZATION SIZES HAVE THE MATCH THE OUTPUT OF THE CORRESPONDING LAYER
        self.batch_norm1 = nn.BatchNorm1d(128)
        self.batch_norm2 = nn.BatchNorm1d(64)
        self.batch_norm3 = nn.BatchNorm1d(32)
        self.batch_norm4 = nn.BatchNorm1d(16)
    
    # "forward pass", if mc_dropout = True => adds a dropout layer between the BayesLinear -layers
    def forward(self, x, mc_dropout=False):
        # NOTE: batch normalization helps in stabilizing the training process
        x = self.batch_norm1(self.relu(self.fc1(x))) 
        x = self.dropout(x) if mc_dropout else x
        x = self.batch_norm2(self.relu(self.fc2(x)))
        x = self.dropout(x) if mc_dropout else x
        x = self.batch_norm3(self.relu(self.fc3(x)))
        x = self.dropout(x) if mc_dropout else x
        x = self.batch_norm4(self.relu(self.fc4(x)))
        x = self.dropout(x) if mc_dropout else x
        return self.fc5(x)

# %% [markdown]
# ### Hyperparameters and model initialization

# %%
# model, loss, optimizer
# NOTE! Regression, OUTPUT DIMENSION IS 1 VARIABLE!
model = BayesianNN(input_dim=X.shape[1], 
                   output_dim=1,
                   sigma=sigma,
                   mu=mu
                   )

# Loss function for REGRESSION
criterion = nn.MSELoss() 

# Bayesian KL Divergence Loss (efficient regularization for BNN)
bkl_loss = bnn.BKLLoss(reduction='mean')  

# AdamW is common in BNN
optimizer = optim.AdamW(model.parameters(), lr=bnn_learning_rate, weight_decay=bnn_weight_decay)

# %% [markdown]
# ### Create train/evaluate -functions for BNN training/evaluation

# %% [markdown]
# #### NOTE! TRAIN AND EVALUATION ARE DIFFERENT IN REGRESSION DUE TO LOSS CALCULATIONS!

# %%
# Evaluate function with uncertainty estimation
def evaluate(model, loader, mc_samples=50):
    model.eval() # Set model to evaluation mode
    total_loss = 0
    uncertainties = []

    with torch.no_grad():
        for X_batch, y_batch in loader:
            outputs_list = [model(X_batch, mc_dropout=True) for _ in range(mc_samples)]
            outputs_stack = torch.stack(outputs_list)  # Shape: (mc_samples, batch_size, num_classes)
            outputs_mean = outputs_stack.mean(dim=0)  # Average prediction
            outputs_std = outputs_stack.std(dim=0)  # Standard deviation (uncertainty)

            loss = criterion(outputs_mean, y_batch)
            total_loss += loss.item()


            uncertainties.extend(outputs_std.mean(dim=1).cpu().numpy())  # Store uncertainty per sample

    r2 = r2_score(y_batch.cpu().numpy(), outputs_mean.cpu().numpy())  # Use R^2 score for regression tasks
    avg_loss = total_loss / len(loader) # Average loss across all batches
    avg_uncertainty = np.mean(uncertainties)  # Average uncertainty across all samples

    print(f"Val. confidence score: {r2:.4f}, Val. loss: {avg_loss:.4f}, Avg. Uncertainty: {avg_uncertainty:.4f}")

    return r2, avg_loss, avg_uncertainty, uncertainties  # Return per-sample uncertainty if needed

# Training loop with BKLLoss
def train(model, loader, epochs=50):
    model.train()
    history = {}
    history['train_loss'] = []
    history['val_loss'] = []
    history['r2'] = []
    history['avg_uncertainty'] = []
    for epoch in range(epochs):
        total_loss = 0
        for X_batch, y_batch in loader:
            optimizer.zero_grad()
            outputs = model(X_batch, mc_dropout=True)
            target_loss = criterion(outputs, y_batch) # Compute target loss
            kl_loss = bkl_loss(model)  # Compute BKL loss
            loss = target_loss + lambda_kl * kl_loss  # Combine losses
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        print(f"Epoch {epoch+1}/{epochs}, Training Loss: {total_loss/len(loader):.4f}")

        r2, val_loss, avg_uncertainty, _ = evaluate(model, val_loader)
        history['train_loss'].append(total_loss / len(loader))
        history['val_loss'].append(val_loss)
        history['r2'].append(r2)
        history['avg_uncertainty'].append(avg_uncertainty)

        # set model to training mode for next epoch
        model.train()
        
    return history

# %% [markdown]
# ### TRAIN THE BNN MODEL!

# %%
# train the model (fit), epochs are usually 1000-5000 with BNN classification
# here we can see how quickly the amount of data slows down the training process
history = train(model, train_loader, epochs=3500)
# Out:
# Epoch 1/3500, Training Loss: 4.1615
# Val. confidence score: -0.8987, Val. loss: 1.3810, Avg. Uncertainty: 2.9116
# Epoch 2/3500, Training Loss: 5.2781
# Val. confidence score: 0.2627, Val. loss: 1.0122, Avg. Uncertainty: 1.5526
# Epoch 3/3500, Training Loss: 4.7953
# Val. confidence score: -0.1418, Val. loss: 1.1302, Avg. Uncertainty: 1.2689
# Epoch 4/3500, Training Loss: 4.4292
# Val. confidence score: -0.3172, Val. loss: 1.1564, Avg. Uncertainty: 1.2093
# Epoch 5/3500, Training Loss: 4.9293
# Val. confidence score: -0.1972, Val. loss: 1.0957, Avg. Uncertainty: 1.2179
# Epoch 6/3500, Training Loss: 5.9011
# Val. confidence score: -0.3660, Val. loss: 1.2116, Avg. Uncertainty: 1.2246
# Epoch 7/3500, Training Loss: 4.5629
# Val. confidence score: -0.1456, Val. loss: 1.1662, Avg. Uncertainty: 1.1787
# Epoch 8/3500, Training Loss: 5.1168
# Val. confidence score: -0.1989, Val. loss: 1.1135, Avg. Uncertainty: 1.2633
# Epoch 9/3500, Training Loss: 4.6852
# Val. confidence score: 0.0183, Val. loss: 1.0901, Avg. Uncertainty: 1.1867
# Epoch 10/3500, Training Loss: 5.5475
# Val. confidence score: 0.0002, Val. loss: 0.9880, Avg. Uncertainty: 1.1657
# Epoch 11/3500, Training Loss: 4.6883
# Val. confidence score: -0.0198, Val. loss: 1.0856, Avg. Uncertainty: 1.1607
# Epoch 12/3500, Training Loss: 5.3661
# Val. confidence score: -0.1289, Val. loss: 1.1308, Avg. Uncertainty: 1.0673
# Epoch 13/3500, Training Loss: 5.7709
# Val. confidence score: -0.2516, Val. loss: 1.1776, Avg. Uncertainty: 1.0210
# Epoch 14/3500, Training Loss: 4.2726
# Val. confidence score: -0.2034, Val. loss: 1.1632, Avg. Uncertainty: 1.1381
# Epoch 15/3500, Training Loss: 4.9670
# Val. confidence score: -0.3649, Val. loss: 1.1311, Avg. Uncertainty: 1.0895
# Epoch 16/3500, Training Loss: 3.8302
# Val. confidence score: 0.0279, Val. loss: 0.9829, Avg. Uncertainty: 1.1770
# Epoch 17/3500, Training Loss: 4.7502
# Val. confidence score: 0.0895, Val. loss: 0.9935, Avg. Uncertainty: 1.0895
# Epoch 18/3500, Training Loss: 4.3567
# Val. confidence score: 0.0131, Val. loss: 1.0444, Avg. Uncertainty: 1.0116
# Epoch 19/3500, Training Loss: 4.0138
# Val. confidence score: 0.0080, Val. loss: 1.0924, Avg. Uncertainty: 1.1273
# Epoch 20/3500, Training Loss: 3.4489
# Val. confidence score: -0.1341, Val. loss: 1.0487, Avg. Uncertainty: 1.0446
# Epoch 21/3500, Training Loss: 3.6930
# Val. confidence score: -0.1980, Val. loss: 1.0205, Avg. Uncertainty: 1.0506
# Epoch 22/3500, Training Loss: 4.2313
# Val. confidence score: -0.0880, Val. loss: 1.1194, Avg. Uncertainty: 1.1214
# Epoch 23/3500, Training Loss: 4.6903
# Val. confidence score: -0.1250, Val. loss: 1.0173, Avg. Uncertainty: 1.0478
# Epoch 24/3500, Training Loss: 4.4614
# Val. confidence score: -0.2963, Val. loss: 1.1313, Avg. Uncertainty: 1.0268
# Epoch 25/3500, Training Loss: 3.8412
# Val. confidence score: -0.0920, Val. loss: 1.1052, Avg. Uncertainty: 1.0932
# Epoch 26/3500, Training Loss: 4.5016
# Val. confidence score: -0.1790, Val. loss: 1.1327, Avg. Uncertainty: 1.0391
# Epoch 27/3500, Training Loss: 3.4198
# Val. confidence score: -0.1752, Val. loss: 1.0639, Avg. Uncertainty: 0.9977
# Epoch 28/3500, Training Loss: 4.0027
# Val. confidence score: 0.0135, Val. loss: 1.0527, Avg. Uncertainty: 0.9758
# Epoch 29/3500, Training Loss: 5.0756
# Val. confidence score: -0.1286, Val. loss: 1.0734, Avg. Uncertainty: 0.9606
# Epoch 30/3500, Training Loss: 4.2383
# Val. confidence score: -0.1587, Val. loss: 1.0130, Avg. Uncertainty: 0.9312
# Epoch 31/3500, Training Loss: 2.9232
# Val. confidence score: 0.0488, Val. loss: 0.9795, Avg. Uncertainty: 1.0643
# Epoch 32/3500, Training Loss: 4.3096
# Val. confidence score: -0.1258, Val. loss: 1.0642, Avg. Uncertainty: 0.9349
# Epoch 33/3500, Training Loss: 3.1750
# Val. confidence score: -0.2093, Val. loss: 1.0973, Avg. Uncertainty: 0.9470
# Epoch 34/3500, Training Loss: 4.1284
# Val. confidence score: -0.1771, Val. loss: 1.1300, Avg. Uncertainty: 1.0020
# Epoch 35/3500, Training Loss: 3.4418
# Val. confidence score: -0.1047, Val. loss: 1.0999, Avg. Uncertainty: 1.0186
# Epoch 36/3500, Training Loss: 3.4493
# Val. confidence score: -0.1546, Val. loss: 1.0611, Avg. Uncertainty: 0.9437
# Epoch 37/3500, Training Loss: 3.7380
# Val. confidence score: 0.0941, Val. loss: 0.9217, Avg. Uncertainty: 0.8775
# Epoch 38/3500, Training Loss: 2.8319
# Val. confidence score: -0.1471, Val. loss: 1.0126, Avg. Uncertainty: 0.9573
# Epoch 39/3500, Training Loss: 3.3142
# Val. confidence score: 0.1683, Val. loss: 0.9429, Avg. Uncertainty: 0.9222
# Epoch 40/3500, Training Loss: 3.1234
# Val. confidence score: -0.1119, Val. loss: 1.0688, Avg. Uncertainty: 0.9265
# Epoch 41/3500, Training Loss: 3.0720
# Val. confidence score: -0.0862, Val. loss: 1.0261, Avg. Uncertainty: 0.9694
# Epoch 42/3500, Training Loss: 3.9117
# Val. confidence score: 0.1118, Val. loss: 0.9942, Avg. Uncertainty: 0.9012
# Epoch 43/3500, Training Loss: 4.3801
# Val. confidence score: 0.0958, Val. loss: 0.9384, Avg. Uncertainty: 0.9400
# Epoch 44/3500, Training Loss: 2.8809
# Val. confidence score: 0.1332, Val. loss: 0.9578, Avg. Uncertainty: 0.9152
# Epoch 45/3500, Training Loss: 2.6603
# Val. confidence score: -0.1048, Val. loss: 1.0748, Avg. Uncertainty: 0.9030
# Epoch 46/3500, Training Loss: 3.3879
# Val. confidence score: -0.2012, Val. loss: 1.0669, Avg. Uncertainty: 0.8770
# Epoch 47/3500, Training Loss: 3.1773
# Val. confidence score: -0.0702, Val. loss: 1.0851, Avg. Uncertainty: 0.9457
# Epoch 48/3500, Training Loss: 3.2946
# Val. confidence score: 0.0285, Val. loss: 0.9853, Avg. Uncertainty: 0.8580
# Epoch 49/3500, Training Loss: 3.7101
# Val. confidence score: 0.0408, Val. loss: 1.0177, Avg. Uncertainty: 0.9265
# Epoch 50/3500, Training Loss: 3.5096
# Val. confidence score: -0.1086, Val. loss: 1.0653, Avg. Uncertainty: 0.8012
# Epoch 51/3500, Training Loss: 4.0921
# Val. confidence score: -0.0547, Val. loss: 1.0225, Avg. Uncertainty: 0.8773
# Epoch 52/3500, Training Loss: 3.5965
# Val. confidence score: -0.0470, Val. loss: 1.0424, Avg. Uncertainty: 0.8851
# Epoch 53/3500, Training Loss: 2.2291
# Val. confidence score: -0.0172, Val. loss: 1.0617, Avg. Uncertainty: 0.8838
# Epoch 54/3500, Training Loss: 3.0109
# Val. confidence score: -0.0788, Val. loss: 1.0253, Avg. Uncertainty: 0.8712
# Epoch 55/3500, Training Loss: 2.6596
# Val. confidence score: -0.1438, Val. loss: 1.0957, Avg. Uncertainty: 0.9688
# Epoch 56/3500, Training Loss: 3.4263
# Val. confidence score: -0.3401, Val. loss: 1.0498, Avg. Uncertainty: 0.8670
# Epoch 57/3500, Training Loss: 3.1214
# Val. confidence score: 0.0279, Val. loss: 0.9709, Avg. Uncertainty: 0.7893
# Epoch 58/3500, Training Loss: 3.2173
# Val. confidence score: -0.0146, Val. loss: 0.9460, Avg. Uncertainty: 0.8703
# Epoch 59/3500, Training Loss: 3.1621
# Val. confidence score: 0.0057, Val. loss: 1.0182, Avg. Uncertainty: 0.8358
# Epoch 60/3500, Training Loss: 2.5180
# Val. confidence score: 0.1104, Val. loss: 0.9407, Avg. Uncertainty: 0.8797
# Epoch 61/3500, Training Loss: 3.3098
# Val. confidence score: 0.0294, Val. loss: 1.0156, Avg. Uncertainty: 0.9278
# Epoch 62/3500, Training Loss: 2.2909
# Val. confidence score: -0.0075, Val. loss: 0.9697, Avg. Uncertainty: 0.8834
# Epoch 63/3500, Training Loss: 2.8337
# Val. confidence score: -0.2053, Val. loss: 1.1322, Avg. Uncertainty: 0.8913
# Epoch 64/3500, Training Loss: 2.4138
# Val. confidence score: -0.1421, Val. loss: 1.0120, Avg. Uncertainty: 0.8385
# Epoch 65/3500, Training Loss: 2.9147
# Val. confidence score: -0.1004, Val. loss: 1.0676, Avg. Uncertainty: 0.8367
# Epoch 66/3500, Training Loss: 2.3199
# Val. confidence score: -0.1588, Val. loss: 1.1501, Avg. Uncertainty: 0.7813
# Epoch 67/3500, Training Loss: 3.4312
# Val. confidence score: 0.0695, Val. loss: 0.9446, Avg. Uncertainty: 0.8469
# Epoch 68/3500, Training Loss: 3.0131
# Val. confidence score: 0.0509, Val. loss: 0.9806, Avg. Uncertainty: 0.8012
# Epoch 69/3500, Training Loss: 3.0827
# Val. confidence score: -0.1383, Val. loss: 1.0641, Avg. Uncertainty: 0.7731
# Epoch 70/3500, Training Loss: 3.1266
# Val. confidence score: -0.1896, Val. loss: 1.0400, Avg. Uncertainty: 0.8611
# Epoch 71/3500, Training Loss: 2.5337
# Val. confidence score: -0.1720, Val. loss: 1.0986, Avg. Uncertainty: 0.8764
# Epoch 72/3500, Training Loss: 2.5732
# Val. confidence score: -0.0428, Val. loss: 1.0093, Avg. Uncertainty: 0.8215
# Epoch 73/3500, Training Loss: 2.4994
# Val. confidence score: -0.0325, Val. loss: 0.9872, Avg. Uncertainty: 0.7863
# Epoch 74/3500, Training Loss: 2.1935
# Val. confidence score: -0.0135, Val. loss: 1.0350, Avg. Uncertainty: 0.7870
# Epoch 75/3500, Training Loss: 2.9455
# Val. confidence score: -0.0029, Val. loss: 0.9831, Avg. Uncertainty: 0.7434
# Epoch 76/3500, Training Loss: 2.8309
# Val. confidence score: 0.0169, Val. loss: 0.9987, Avg. Uncertainty: 0.7676
# Epoch 77/3500, Training Loss: 2.4634
# Val. confidence score: -0.0474, Val. loss: 0.9844, Avg. Uncertainty: 0.7683
# Epoch 78/3500, Training Loss: 2.7401
# Val. confidence score: 0.0213, Val. loss: 1.0483, Avg. Uncertainty: 0.7076
# Epoch 79/3500, Training Loss: 2.5407
# Val. confidence score: -0.0513, Val. loss: 1.0411, Avg. Uncertainty: 0.6975
# Epoch 80/3500, Training Loss: 2.7171
# Val. confidence score: -0.0451, Val. loss: 1.0119, Avg. Uncertainty: 0.7692
# Epoch 81/3500, Training Loss: 2.5334
# Val. confidence score: 0.0057, Val. loss: 0.9468, Avg. Uncertainty: 0.7744
# Epoch 82/3500, Training Loss: 2.2877
# Val. confidence score: -0.0004, Val. loss: 1.0111, Avg. Uncertainty: 0.7731
# Epoch 83/3500, Training Loss: 2.7700
# Val. confidence score: 0.1622, Val. loss: 0.9797, Avg. Uncertainty: 0.8135
# Epoch 84/3500, Training Loss: 2.5228
# Val. confidence score: 0.0063, Val. loss: 0.9823, Avg. Uncertainty: 0.7760
# Epoch 85/3500, Training Loss: 2.1406
# Val. confidence score: 0.0461, Val. loss: 1.0361, Avg. Uncertainty: 0.8054
# Epoch 86/3500, Training Loss: 2.5931
# Val. confidence score: 0.0209, Val. loss: 0.9999, Avg. Uncertainty: 0.7199
# Epoch 87/3500, Training Loss: 2.7931
# Val. confidence score: -0.0248, Val. loss: 1.0175, Avg. Uncertainty: 0.7607
# Epoch 88/3500, Training Loss: 2.9614
# Val. confidence score: -0.0855, Val. loss: 1.0177, Avg. Uncertainty: 0.7901
# Epoch 89/3500, Training Loss: 1.9699
# Val. confidence score: -0.0385, Val. loss: 0.9639, Avg. Uncertainty: 0.7426
# Epoch 90/3500, Training Loss: 2.7844
# Val. confidence score: 0.0154, Val. loss: 1.0430, Avg. Uncertainty: 0.7544
# Epoch 91/3500, Training Loss: 2.7191
# Val. confidence score: -0.0284, Val. loss: 1.0246, Avg. Uncertainty: 0.6795
# Epoch 92/3500, Training Loss: 3.0203
# Val. confidence score: -0.0379, Val. loss: 1.0194, Avg. Uncertainty: 0.7231
# Epoch 93/3500, Training Loss: 2.9327
# Val. confidence score: -0.1067, Val. loss: 1.0604, Avg. Uncertainty: 0.7253
# Epoch 94/3500, Training Loss: 2.3201
# Val. confidence score: -0.0162, Val. loss: 1.0120, Avg. Uncertainty: 0.7233
# Epoch 95/3500, Training Loss: 1.7213
# Val. confidence score: 0.0222, Val. loss: 1.0445, Avg. Uncertainty: 0.6545
# Epoch 96/3500, Training Loss: 2.5601
# Val. confidence score: -0.0896, Val. loss: 1.0165, Avg. Uncertainty: 0.6955
# Epoch 97/3500, Training Loss: 2.5671
# Val. confidence score: -0.0661, Val. loss: 1.0457, Avg. Uncertainty: 0.7352
# Epoch 98/3500, Training Loss: 2.0909
# Val. confidence score: 0.0098, Val. loss: 0.9985, Avg. Uncertainty: 0.7623
# Epoch 99/3500, Training Loss: 2.9375
# Val. confidence score: 0.0150, Val. loss: 0.9820, Avg. Uncertainty: 0.7122
# Epoch 100/3500, Training Loss: 2.8383
# Val. confidence score: -0.0269, Val. loss: 1.0226, Avg. Uncertainty: 0.6955
# Epoch 101/3500, Training Loss: 2.3871
# Val. confidence score: 0.0061, Val. loss: 0.9947, Avg. Uncertainty: 0.7250
# Epoch 102/3500, Training Loss: 2.1688
# Val. confidence score: -0.0359, Val. loss: 1.0558, Avg. Uncertainty: 0.7061
# Epoch 103/3500, Training Loss: 2.2952
# Val. confidence score: 0.0656, Val. loss: 1.0131, Avg. Uncertainty: 0.6971
# Epoch 104/3500, Training Loss: 2.5675
# Val. confidence score: 0.0241, Val. loss: 1.0116, Avg. Uncertainty: 0.6863
# Epoch 105/3500, Training Loss: 2.1751
# Val. confidence score: -0.0446, Val. loss: 1.0058, Avg. Uncertainty: 0.7190
# Epoch 106/3500, Training Loss: 1.8220
# Val. confidence score: 0.0504, Val. loss: 0.9970, Avg. Uncertainty: 0.7009
# Epoch 107/3500, Training Loss: 1.9136
# Val. confidence score: -0.0407, Val. loss: 1.0298, Avg. Uncertainty: 0.6700
# Epoch 108/3500, Training Loss: 2.4323
# Val. confidence score: 0.0025, Val. loss: 1.0591, Avg. Uncertainty: 0.6894
# Epoch 109/3500, Training Loss: 2.1108
# Val. confidence score: -0.0196, Val. loss: 1.0131, Avg. Uncertainty: 0.7306
# Epoch 110/3500, Training Loss: 1.7604
# Val. confidence score: -0.0914, Val. loss: 1.0474, Avg. Uncertainty: 0.6383
# Epoch 111/3500, Training Loss: 2.2773
# Val. confidence score: 0.0167, Val. loss: 0.9859, Avg. Uncertainty: 0.7050
# Epoch 112/3500, Training Loss: 2.2048
# Val. confidence score: 0.0280, Val. loss: 1.0225, Avg. Uncertainty: 0.6478
# Epoch 113/3500, Training Loss: 1.9240
# Val. confidence score: -0.0602, Val. loss: 1.0325, Avg. Uncertainty: 0.7002
# Epoch 114/3500, Training Loss: 1.8954
# Val. confidence score: 0.0270, Val. loss: 1.0021, Avg. Uncertainty: 0.5810
# Epoch 115/3500, Training Loss: 1.7740
# Val. confidence score: -0.0234, Val. loss: 0.9965, Avg. Uncertainty: 0.6675
# Epoch 116/3500, Training Loss: 2.6440
# Val. confidence score: -0.0341, Val. loss: 1.0333, Avg. Uncertainty: 0.7165
# Epoch 117/3500, Training Loss: 2.2634
# Val. confidence score: -0.0048, Val. loss: 0.9861, Avg. Uncertainty: 0.6557
# Epoch 118/3500, Training Loss: 2.3365
# Val. confidence score: -0.0676, Val. loss: 1.0059, Avg. Uncertainty: 0.6491
# Epoch 119/3500, Training Loss: 1.9439
# Val. confidence score: -0.1717, Val. loss: 1.0390, Avg. Uncertainty: 0.6484
# Epoch 120/3500, Training Loss: 1.7507
# Val. confidence score: -0.0405, Val. loss: 1.0256, Avg. Uncertainty: 0.6690
# Epoch 121/3500, Training Loss: 1.7635
# Val. confidence score: -0.0067, Val. loss: 1.0006, Avg. Uncertainty: 0.6695
# Epoch 122/3500, Training Loss: 1.8505
# Val. confidence score: 0.0304, Val. loss: 0.9649, Avg. Uncertainty: 0.6192
# Epoch 123/3500, Training Loss: 2.0140
# Val. confidence score: -0.0682, Val. loss: 1.0232, Avg. Uncertainty: 0.6219
# Epoch 124/3500, Training Loss: 2.1063
# Val. confidence score: 0.0389, Val. loss: 1.0029, Avg. Uncertainty: 0.6392
# Epoch 125/3500, Training Loss: 1.7491
# Val. confidence score: -0.0459, Val. loss: 1.0515, Avg. Uncertainty: 0.6333
# Epoch 126/3500, Training Loss: 1.6808
# Val. confidence score: -0.0497, Val. loss: 1.0213, Avg. Uncertainty: 0.6205
# Epoch 127/3500, Training Loss: 1.9162
# Val. confidence score: -0.0135, Val. loss: 1.0142, Avg. Uncertainty: 0.6218
# Epoch 128/3500, Training Loss: 1.7110
# Val. confidence score: -0.0532, Val. loss: 1.0639, Avg. Uncertainty: 0.6057
# Epoch 129/3500, Training Loss: 1.8522
# Val. confidence score: -0.0150, Val. loss: 1.0225, Avg. Uncertainty: 0.6248
# Epoch 130/3500, Training Loss: 1.5808
# Val. confidence score: -0.0583, Val. loss: 0.9920, Avg. Uncertainty: 0.6125
# Epoch 131/3500, Training Loss: 2.3080
# Val. confidence score: -0.0974, Val. loss: 1.0132, Avg. Uncertainty: 0.6516
# Epoch 132/3500, Training Loss: 1.8199
# Val. confidence score: 0.0444, Val. loss: 0.9430, Avg. Uncertainty: 0.6130
# Epoch 133/3500, Training Loss: 1.6353
# Val. confidence score: -0.0342, Val. loss: 0.9810, Avg. Uncertainty: 0.6192
# Epoch 134/3500, Training Loss: 1.7885
# Val. confidence score: -0.0613, Val. loss: 1.0075, Avg. Uncertainty: 0.6198
# Epoch 135/3500, Training Loss: 1.8484
# Val. confidence score: 0.0298, Val. loss: 0.9904, Avg. Uncertainty: 0.6010
# Epoch 136/3500, Training Loss: 2.0322
# Val. confidence score: -0.1022, Val. loss: 1.0742, Avg. Uncertainty: 0.6345
# Epoch 137/3500, Training Loss: 1.8929
# Val. confidence score: 0.0105, Val. loss: 0.9623, Avg. Uncertainty: 0.6063
# Epoch 138/3500, Training Loss: 1.7222
# Val. confidence score: 0.0053, Val. loss: 1.0250, Avg. Uncertainty: 0.6100
# Epoch 139/3500, Training Loss: 1.7566
# Val. confidence score: -0.0166, Val. loss: 0.9921, Avg. Uncertainty: 0.6210
# Epoch 140/3500, Training Loss: 1.9783
# Val. confidence score: 0.0350, Val. loss: 0.9842, Avg. Uncertainty: 0.5628
# Epoch 141/3500, Training Loss: 2.2105
# Val. confidence score: -0.0202, Val. loss: 0.9963, Avg. Uncertainty: 0.5846
# Epoch 142/3500, Training Loss: 1.9086
# Val. confidence score: -0.0146, Val. loss: 0.9939, Avg. Uncertainty: 0.6413
# Epoch 143/3500, Training Loss: 1.8073
# Val. confidence score: 0.0207, Val. loss: 0.9997, Avg. Uncertainty: 0.6151
# Epoch 144/3500, Training Loss: 1.9979
# Val. confidence score: 0.0601, Val. loss: 0.9708, Avg. Uncertainty: 0.5777
# Epoch 145/3500, Training Loss: 2.0497
# Val. confidence score: -0.0067, Val. loss: 1.0333, Avg. Uncertainty: 0.5905
# Epoch 146/3500, Training Loss: 2.0438
# Val. confidence score: 0.0914, Val. loss: 0.9881, Avg. Uncertainty: 0.6070
# Epoch 147/3500, Training Loss: 1.8763
# Val. confidence score: -0.0915, Val. loss: 1.0074, Avg. Uncertainty: 0.5779
# Epoch 148/3500, Training Loss: 1.9118
# Val. confidence score: 0.0454, Val. loss: 1.0007, Avg. Uncertainty: 0.5605
# Epoch 149/3500, Training Loss: 1.9268
# Val. confidence score: -0.0723, Val. loss: 0.9962, Avg. Uncertainty: 0.5564
# Epoch 150/3500, Training Loss: 1.6375
# Val. confidence score: -0.0421, Val. loss: 1.0191, Avg. Uncertainty: 0.5863
# Epoch 151/3500, Training Loss: 1.8410
# Val. confidence score: 0.0455, Val. loss: 0.9912, Avg. Uncertainty: 0.5899
# Epoch 152/3500, Training Loss: 1.5791
# Val. confidence score: -0.0405, Val. loss: 1.0140, Avg. Uncertainty: 0.5371
# Epoch 153/3500, Training Loss: 1.4985
# Val. confidence score: -0.0570, Val. loss: 1.0518, Avg. Uncertainty: 0.5252
# Epoch 154/3500, Training Loss: 2.1471
# Val. confidence score: -0.0019, Val. loss: 0.9968, Avg. Uncertainty: 0.6113
# Epoch 155/3500, Training Loss: 2.3558
# Val. confidence score: -0.0049, Val. loss: 1.0168, Avg. Uncertainty: 0.5882
# Epoch 156/3500, Training Loss: 1.7720
# Val. confidence score: 0.0349, Val. loss: 0.9901, Avg. Uncertainty: 0.5563
# Epoch 157/3500, Training Loss: 1.8350
# Val. confidence score: 0.0038, Val. loss: 1.0212, Avg. Uncertainty: 0.5470
# Epoch 158/3500, Training Loss: 2.2875
# Val. confidence score: 0.0193, Val. loss: 1.0146, Avg. Uncertainty: 0.5878
# Epoch 159/3500, Training Loss: 1.5038
# Val. confidence score: -0.0952, Val. loss: 1.0511, Avg. Uncertainty: 0.5347
# Epoch 160/3500, Training Loss: 1.7438
# Val. confidence score: -0.0343, Val. loss: 1.0055, Avg. Uncertainty: 0.5590
# Epoch 161/3500, Training Loss: 1.6150
# Val. confidence score: -0.0030, Val. loss: 1.0040, Avg. Uncertainty: 0.5720
# Epoch 162/3500, Training Loss: 1.7397
# Val. confidence score: 0.0460, Val. loss: 0.9691, Avg. Uncertainty: 0.6077
# Epoch 163/3500, Training Loss: 1.8216
# Val. confidence score: -0.0383, Val. loss: 0.9964, Avg. Uncertainty: 0.5597
# Epoch 164/3500, Training Loss: 1.9417
# Val. confidence score: 0.0844, Val. loss: 0.9957, Avg. Uncertainty: 0.5560
# Epoch 165/3500, Training Loss: 1.6594
# Val. confidence score: -0.0589, Val. loss: 1.0143, Avg. Uncertainty: 0.5227
# Epoch 166/3500, Training Loss: 1.7172
# Val. confidence score: -0.0492, Val. loss: 1.0496, Avg. Uncertainty: 0.5317
# Epoch 167/3500, Training Loss: 1.6668
# Val. confidence score: -0.0057, Val. loss: 1.0210, Avg. Uncertainty: 0.5136
# Epoch 168/3500, Training Loss: 1.9355
# Val. confidence score: 0.0264, Val. loss: 1.0060, Avg. Uncertainty: 0.5227
# Epoch 169/3500, Training Loss: 1.5501
# Val. confidence score: -0.0145, Val. loss: 1.0139, Avg. Uncertainty: 0.5273
# Epoch 170/3500, Training Loss: 1.5974
# Val. confidence score: 0.0875, Val. loss: 1.0089, Avg. Uncertainty: 0.5204
# Epoch 171/3500, Training Loss: 1.3392
# Val. confidence score: -0.0432, Val. loss: 1.0018, Avg. Uncertainty: 0.5195
# Epoch 172/3500, Training Loss: 1.6777
# Val. confidence score: 0.0840, Val. loss: 0.9889, Avg. Uncertainty: 0.5429
# Epoch 173/3500, Training Loss: 1.5741
# Val. confidence score: 0.0016, Val. loss: 1.0141, Avg. Uncertainty: 0.5423
# Epoch 174/3500, Training Loss: 1.5405
# Val. confidence score: -0.0320, Val. loss: 0.9951, Avg. Uncertainty: 0.5330
# Epoch 175/3500, Training Loss: 1.3687
# Val. confidence score: 0.0169, Val. loss: 1.0460, Avg. Uncertainty: 0.5481
# Epoch 176/3500, Training Loss: 1.5649
# Val. confidence score: -0.0081, Val. loss: 1.0116, Avg. Uncertainty: 0.5095
# Epoch 177/3500, Training Loss: 1.7243
# Val. confidence score: -0.0305, Val. loss: 1.0151, Avg. Uncertainty: 0.5124
# Epoch 178/3500, Training Loss: 1.5512
# Val. confidence score: 0.0824, Val. loss: 0.9854, Avg. Uncertainty: 0.5269
# Epoch 179/3500, Training Loss: 1.4677
# Val. confidence score: 0.0142, Val. loss: 0.9829, Avg. Uncertainty: 0.4849
# Epoch 180/3500, Training Loss: 1.5988
# Val. confidence score: 0.0600, Val. loss: 0.9914, Avg. Uncertainty: 0.5287
# Epoch 181/3500, Training Loss: 1.2088
# Val. confidence score: 0.0448, Val. loss: 0.9727, Avg. Uncertainty: 0.5447
# Epoch 182/3500, Training Loss: 1.5417
# Val. confidence score: 0.0045, Val. loss: 0.9763, Avg. Uncertainty: 0.4962
# Epoch 183/3500, Training Loss: 1.7894
# Val. confidence score: -0.0415, Val. loss: 0.9749, Avg. Uncertainty: 0.5581
# Epoch 184/3500, Training Loss: 1.6214
# Val. confidence score: 0.0241, Val. loss: 1.0354, Avg. Uncertainty: 0.4961
# Epoch 185/3500, Training Loss: 1.4983
# Val. confidence score: 0.0601, Val. loss: 0.9824, Avg. Uncertainty: 0.4893
# Epoch 186/3500, Training Loss: 1.6185
# Val. confidence score: 0.0392, Val. loss: 0.9999, Avg. Uncertainty: 0.4892
# Epoch 187/3500, Training Loss: 1.3847
# Val. confidence score: -0.0685, Val. loss: 1.0378, Avg. Uncertainty: 0.4390
# Epoch 188/3500, Training Loss: 1.3769
# Val. confidence score: 0.0861, Val. loss: 0.9683, Avg. Uncertainty: 0.4900
# Epoch 189/3500, Training Loss: 1.7387
# Val. confidence score: -0.0088, Val. loss: 1.0235, Avg. Uncertainty: 0.5130
# Epoch 190/3500, Training Loss: 1.7102
# Val. confidence score: 0.0136, Val. loss: 0.9984, Avg. Uncertainty: 0.4991
# Epoch 191/3500, Training Loss: 1.7994
# Val. confidence score: 0.0640, Val. loss: 0.9794, Avg. Uncertainty: 0.4814
# Epoch 192/3500, Training Loss: 1.5936
# Val. confidence score: 0.0552, Val. loss: 0.9940, Avg. Uncertainty: 0.5126
# Epoch 193/3500, Training Loss: 1.3763
# Val. confidence score: -0.0063, Val. loss: 0.9977, Avg. Uncertainty: 0.5052
# Epoch 194/3500, Training Loss: 1.2985
# Val. confidence score: 0.0124, Val. loss: 0.9946, Avg. Uncertainty: 0.5260
# Epoch 195/3500, Training Loss: 1.5857
# Val. confidence score: -0.0461, Val. loss: 1.0000, Avg. Uncertainty: 0.5159
# Epoch 196/3500, Training Loss: 1.5419
# Val. confidence score: 0.0011, Val. loss: 1.0129, Avg. Uncertainty: 0.4670
# Epoch 197/3500, Training Loss: 1.5685
# Val. confidence score: -0.0863, Val. loss: 1.0123, Avg. Uncertainty: 0.4616
# Epoch 198/3500, Training Loss: 1.6187
# Val. confidence score: -0.0798, Val. loss: 0.9891, Avg. Uncertainty: 0.4672
# Epoch 199/3500, Training Loss: 1.5538
# Val. confidence score: -0.0778, Val. loss: 1.0274, Avg. Uncertainty: 0.5054
# Epoch 200/3500, Training Loss: 1.2488
# Val. confidence score: 0.0172, Val. loss: 1.0182, Avg. Uncertainty: 0.4704
# Epoch 201/3500, Training Loss: 1.3160
# Val. confidence score: -0.0049, Val. loss: 1.0013, Avg. Uncertainty: 0.4692
# Epoch 202/3500, Training Loss: 1.3862
# Val. confidence score: 0.0837, Val. loss: 0.9821, Avg. Uncertainty: 0.4550
# Epoch 203/3500, Training Loss: 1.6327
# Val. confidence score: -0.0450, Val. loss: 0.9980, Avg. Uncertainty: 0.4531
# Epoch 204/3500, Training Loss: 1.5364
# Val. confidence score: -0.0238, Val. loss: 1.0185, Avg. Uncertainty: 0.4609
# Epoch 205/3500, Training Loss: 1.7478
# Val. confidence score: -0.0135, Val. loss: 1.0354, Avg. Uncertainty: 0.4538
# Epoch 206/3500, Training Loss: 1.4065
# Val. confidence score: 0.0521, Val. loss: 0.9979, Avg. Uncertainty: 0.4740
# Epoch 207/3500, Training Loss: 1.5093
# Val. confidence score: 0.0402, Val. loss: 0.9941, Avg. Uncertainty: 0.4941
# Epoch 208/3500, Training Loss: 1.4871
# Val. confidence score: 0.0250, Val. loss: 1.0055, Avg. Uncertainty: 0.4729
# Epoch 209/3500, Training Loss: 1.4814
# Val. confidence score: 0.0312, Val. loss: 1.0056, Avg. Uncertainty: 0.4685
# Epoch 210/3500, Training Loss: 1.4269
# Val. confidence score: 0.0910, Val. loss: 0.9756, Avg. Uncertainty: 0.4774
# Epoch 211/3500, Training Loss: 1.2995
# Val. confidence score: 0.0125, Val. loss: 0.9960, Avg. Uncertainty: 0.4727
# Epoch 212/3500, Training Loss: 1.2604
# Val. confidence score: 0.0924, Val. loss: 0.9993, Avg. Uncertainty: 0.4851
# Epoch 213/3500, Training Loss: 1.4142
# Val. confidence score: -0.0520, Val. loss: 1.0328, Avg. Uncertainty: 0.4600
# Epoch 214/3500, Training Loss: 1.2498
# Val. confidence score: -0.0512, Val. loss: 1.0314, Avg. Uncertainty: 0.4627
# Epoch 215/3500, Training Loss: 1.5062
# Val. confidence score: 0.0427, Val. loss: 0.9833, Avg. Uncertainty: 0.4291
# Epoch 216/3500, Training Loss: 1.4734
# Val. confidence score: -0.0057, Val. loss: 0.9955, Avg. Uncertainty: 0.4465
# Epoch 217/3500, Training Loss: 1.4741
# Val. confidence score: 0.0948, Val. loss: 0.9332, Avg. Uncertainty: 0.4545
# Epoch 218/3500, Training Loss: 1.4535
# Val. confidence score: -0.0086, Val. loss: 0.9850, Avg. Uncertainty: 0.4805
# Epoch 219/3500, Training Loss: 1.2792
# Val. confidence score: -0.0107, Val. loss: 1.0173, Avg. Uncertainty: 0.4470
# Epoch 220/3500, Training Loss: 1.5854
# Val. confidence score: 0.0386, Val. loss: 0.9917, Avg. Uncertainty: 0.4334
# Epoch 221/3500, Training Loss: 1.5141
# Val. confidence score: 0.0409, Val. loss: 0.9869, Avg. Uncertainty: 0.4453
# Epoch 222/3500, Training Loss: 1.3217
# Val. confidence score: 0.0252, Val. loss: 0.9860, Avg. Uncertainty: 0.4698
# Epoch 223/3500, Training Loss: 1.4389
# Val. confidence score: 0.0244, Val. loss: 0.9635, Avg. Uncertainty: 0.4246
# Epoch 224/3500, Training Loss: 1.5842
# Val. confidence score: 0.0062, Val. loss: 0.9816, Avg. Uncertainty: 0.4184
# Epoch 225/3500, Training Loss: 1.4429
# Val. confidence score: 0.0165, Val. loss: 1.0016, Avg. Uncertainty: 0.4142
# Epoch 226/3500, Training Loss: 1.3147
# Val. confidence score: -0.0206, Val. loss: 0.9733, Avg. Uncertainty: 0.4416
# Epoch 227/3500, Training Loss: 1.2335
# Val. confidence score: -0.1082, Val. loss: 1.0253, Avg. Uncertainty: 0.4069
# Epoch 228/3500, Training Loss: 1.2675
# Val. confidence score: 0.0866, Val. loss: 0.9704, Avg. Uncertainty: 0.4491
# Epoch 229/3500, Training Loss: 1.4780
# Val. confidence score: -0.0032, Val. loss: 1.0055, Avg. Uncertainty: 0.4345
# Epoch 230/3500, Training Loss: 1.4799
# Val. confidence score: 0.0345, Val. loss: 0.9829, Avg. Uncertainty: 0.4464
# Epoch 231/3500, Training Loss: 1.2886
# Val. confidence score: 0.0280, Val. loss: 0.9949, Avg. Uncertainty: 0.4429
# Epoch 232/3500, Training Loss: 1.3566
# Val. confidence score: 0.0662, Val. loss: 0.9571, Avg. Uncertainty: 0.4085
# Epoch 233/3500, Training Loss: 1.3491
# Val. confidence score: 0.0451, Val. loss: 0.9974, Avg. Uncertainty: 0.4480
# Epoch 234/3500, Training Loss: 1.5065
# Val. confidence score: -0.0296, Val. loss: 1.0244, Avg. Uncertainty: 0.4040
# Epoch 235/3500, Training Loss: 1.4683
# Val. confidence score: -0.0176, Val. loss: 0.9990, Avg. Uncertainty: 0.4297
# Epoch 236/3500, Training Loss: 1.3793
# Val. confidence score: 0.0205, Val. loss: 0.9946, Avg. Uncertainty: 0.3973
# Epoch 237/3500, Training Loss: 1.3248
# Val. confidence score: 0.0354, Val. loss: 0.9756, Avg. Uncertainty: 0.4136
# Epoch 238/3500, Training Loss: 1.5195
# Val. confidence score: 0.0228, Val. loss: 1.0001, Avg. Uncertainty: 0.4419
# Epoch 239/3500, Training Loss: 1.4014
# Val. confidence score: 0.0233, Val. loss: 0.9820, Avg. Uncertainty: 0.4426
# Epoch 240/3500, Training Loss: 1.3935
# Val. confidence score: 0.0668, Val. loss: 0.9795, Avg. Uncertainty: 0.4274
# Epoch 241/3500, Training Loss: 1.4176
# Val. confidence score: -0.0148, Val. loss: 1.0061, Avg. Uncertainty: 0.4573
# Epoch 242/3500, Training Loss: 1.3416
# Val. confidence score: 0.0522, Val. loss: 0.9879, Avg. Uncertainty: 0.4157
# Epoch 243/3500, Training Loss: 1.1348
# Val. confidence score: -0.0211, Val. loss: 1.0145, Avg. Uncertainty: 0.4118
# Epoch 244/3500, Training Loss: 1.2099
# Val. confidence score: -0.0348, Val. loss: 1.0203, Avg. Uncertainty: 0.4372
# Epoch 245/3500, Training Loss: 1.1411
# Val. confidence score: 0.0003, Val. loss: 0.9984, Avg. Uncertainty: 0.4190
# Epoch 246/3500, Training Loss: 1.4461
# Val. confidence score: -0.0231, Val. loss: 1.0102, Avg. Uncertainty: 0.4058
# Epoch 247/3500, Training Loss: 1.2395
# Val. confidence score: -0.0288, Val. loss: 0.9951, Avg. Uncertainty: 0.3893
# Epoch 248/3500, Training Loss: 1.2133
# Val. confidence score: 0.0227, Val. loss: 0.9761, Avg. Uncertainty: 0.4094
# Epoch 249/3500, Training Loss: 1.1858
# Val. confidence score: 0.0705, Val. loss: 0.9538, Avg. Uncertainty: 0.4447
# Epoch 250/3500, Training Loss: 1.2295
# Val. confidence score: -0.0484, Val. loss: 1.0206, Avg. Uncertainty: 0.3844
# Epoch 251/3500, Training Loss: 1.1869
# Val. confidence score: -0.0053, Val. loss: 0.9954, Avg. Uncertainty: 0.3969
# Epoch 252/3500, Training Loss: 1.3849
# Val. confidence score: -0.0001, Val. loss: 1.0017, Avg. Uncertainty: 0.3872
# Epoch 253/3500, Training Loss: 1.2649
# Val. confidence score: 0.0720, Val. loss: 0.9717, Avg. Uncertainty: 0.3977
# Epoch 254/3500, Training Loss: 1.1525
# Val. confidence score: -0.0131, Val. loss: 1.0023, Avg. Uncertainty: 0.4015
# Epoch 255/3500, Training Loss: 1.1440
# Val. confidence score: 0.0309, Val. loss: 1.0103, Avg. Uncertainty: 0.3855
# Epoch 256/3500, Training Loss: 1.3007
# Val. confidence score: 0.0418, Val. loss: 0.9739, Avg. Uncertainty: 0.3700
# Epoch 257/3500, Training Loss: 1.3170
# Val. confidence score: -0.0663, Val. loss: 1.0047, Avg. Uncertainty: 0.4058
# Epoch 258/3500, Training Loss: 1.2007
# Val. confidence score: 0.0366, Val. loss: 0.9858, Avg. Uncertainty: 0.4045
# Epoch 259/3500, Training Loss: 1.4039
# Val. confidence score: 0.0926, Val. loss: 0.9435, Avg. Uncertainty: 0.3825
# Epoch 260/3500, Training Loss: 1.4349
# Val. confidence score: -0.0477, Val. loss: 1.0102, Avg. Uncertainty: 0.3998
# Epoch 261/3500, Training Loss: 1.2528
# Val. confidence score: 0.0449, Val. loss: 0.9659, Avg. Uncertainty: 0.4206
# Epoch 262/3500, Training Loss: 1.0239
# Val. confidence score: 0.0152, Val. loss: 0.9856, Avg. Uncertainty: 0.3887
# Epoch 263/3500, Training Loss: 1.2347
# Val. confidence score: 0.0021, Val. loss: 0.9861, Avg. Uncertainty: 0.3799
# Epoch 264/3500, Training Loss: 1.1794
# Val. confidence score: 0.0172, Val. loss: 0.9747, Avg. Uncertainty: 0.3673
# Epoch 265/3500, Training Loss: 1.1980
# Val. confidence score: 0.0633, Val. loss: 0.9926, Avg. Uncertainty: 0.3814
# Epoch 266/3500, Training Loss: 1.3952
# Val. confidence score: 0.0305, Val. loss: 0.9634, Avg. Uncertainty: 0.3790
# Epoch 267/3500, Training Loss: 1.2243
# Val. confidence score: 0.0071, Val. loss: 0.9912, Avg. Uncertainty: 0.4122
# Epoch 268/3500, Training Loss: 1.2510
# Val. confidence score: 0.0336, Val. loss: 0.9725, Avg. Uncertainty: 0.3743
# Epoch 269/3500, Training Loss: 1.4438
# Val. confidence score: 0.0431, Val. loss: 0.9857, Avg. Uncertainty: 0.3923
# Epoch 270/3500, Training Loss: 1.3908
# Val. confidence score: -0.0154, Val. loss: 1.0006, Avg. Uncertainty: 0.3893
# Epoch 271/3500, Training Loss: 1.3482
# Val. confidence score: -0.0554, Val. loss: 0.9872, Avg. Uncertainty: 0.3655
# Epoch 272/3500, Training Loss: 1.1922
# Val. confidence score: -0.0213, Val. loss: 1.0019, Avg. Uncertainty: 0.3564
# Epoch 273/3500, Training Loss: 1.2339
# Val. confidence score: 0.0487, Val. loss: 0.9835, Avg. Uncertainty: 0.3709
# Epoch 274/3500, Training Loss: 1.2037
# Val. confidence score: 0.0240, Val. loss: 1.0149, Avg. Uncertainty: 0.3929
# Epoch 275/3500, Training Loss: 1.0707
# Val. confidence score: 0.0135, Val. loss: 0.9875, Avg. Uncertainty: 0.3666
# Epoch 276/3500, Training Loss: 1.2109
# Val. confidence score: -0.0009, Val. loss: 0.9960, Avg. Uncertainty: 0.3704
# Epoch 277/3500, Training Loss: 1.2688
# Val. confidence score: 0.0499, Val. loss: 0.9701, Avg. Uncertainty: 0.3440
# Epoch 278/3500, Training Loss: 1.1798
# Val. confidence score: 0.0394, Val. loss: 0.9605, Avg. Uncertainty: 0.3702
# Epoch 279/3500, Training Loss: 1.2642
# Val. confidence score: -0.0319, Val. loss: 0.9869, Avg. Uncertainty: 0.3609
# Epoch 280/3500, Training Loss: 1.2859
# Val. confidence score: -0.0293, Val. loss: 1.0244, Avg. Uncertainty: 0.3322
# Epoch 281/3500, Training Loss: 1.2023
# Val. confidence score: 0.0124, Val. loss: 0.9892, Avg. Uncertainty: 0.3389
# Epoch 282/3500, Training Loss: 1.2845
# Val. confidence score: 0.0354, Val. loss: 0.9844, Avg. Uncertainty: 0.3851
# Epoch 283/3500, Training Loss: 1.3283
# Val. confidence score: 0.0074, Val. loss: 0.9863, Avg. Uncertainty: 0.3791
# Epoch 284/3500, Training Loss: 1.2693
# Val. confidence score: -0.0251, Val. loss: 0.9844, Avg. Uncertainty: 0.3437
# Epoch 285/3500, Training Loss: 1.1323
# Val. confidence score: 0.0250, Val. loss: 1.0179, Avg. Uncertainty: 0.3677
# Epoch 286/3500, Training Loss: 1.0802
# Val. confidence score: 0.0306, Val. loss: 0.9668, Avg. Uncertainty: 0.3486
# Epoch 287/3500, Training Loss: 1.1348
# Val. confidence score: 0.0588, Val. loss: 0.9926, Avg. Uncertainty: 0.3553
# Epoch 288/3500, Training Loss: 1.2372
# Val. confidence score: 0.0167, Val. loss: 1.0004, Avg. Uncertainty: 0.3890
# Epoch 289/3500, Training Loss: 1.3972
# Val. confidence score: -0.0317, Val. loss: 1.0060, Avg. Uncertainty: 0.3777
# Epoch 290/3500, Training Loss: 1.3176
# Val. confidence score: -0.0071, Val. loss: 0.9935, Avg. Uncertainty: 0.3482
# Epoch 291/3500, Training Loss: 1.2251
# Val. confidence score: 0.0016, Val. loss: 0.9811, Avg. Uncertainty: 0.3616
# Epoch 292/3500, Training Loss: 1.2843
# Val. confidence score: 0.0537, Val. loss: 0.9893, Avg. Uncertainty: 0.3352
# Epoch 293/3500, Training Loss: 1.0895
# Val. confidence score: 0.0241, Val. loss: 1.0026, Avg. Uncertainty: 0.3391
# Epoch 294/3500, Training Loss: 1.1216
# Val. confidence score: 0.0074, Val. loss: 0.9882, Avg. Uncertainty: 0.3687
# Epoch 295/3500, Training Loss: 1.1604
# Val. confidence score: -0.0010, Val. loss: 1.0063, Avg. Uncertainty: 0.3470
# Epoch 296/3500, Training Loss: 1.2721
# Val. confidence score: 0.0170, Val. loss: 0.9905, Avg. Uncertainty: 0.3389
# Epoch 297/3500, Training Loss: 1.1241
# Val. confidence score: 0.0458, Val. loss: 0.9485, Avg. Uncertainty: 0.3455
# Epoch 298/3500, Training Loss: 1.2670
# Val. confidence score: 0.0490, Val. loss: 0.9887, Avg. Uncertainty: 0.3511
# Epoch 299/3500, Training Loss: 1.0915
# Val. confidence score: 0.0123, Val. loss: 0.9886, Avg. Uncertainty: 0.3668
# Epoch 300/3500, Training Loss: 1.2262
# Val. confidence score: 0.0044, Val. loss: 0.9995, Avg. Uncertainty: 0.3601
# Epoch 301/3500, Training Loss: 1.2390
# Val. confidence score: 0.0313, Val. loss: 0.9840, Avg. Uncertainty: 0.3417
# Epoch 302/3500, Training Loss: 1.2147
# Val. confidence score: 0.0132, Val. loss: 0.9838, Avg. Uncertainty: 0.3216
# Epoch 303/3500, Training Loss: 1.1236
# Val. confidence score: 0.0765, Val. loss: 0.9672, Avg. Uncertainty: 0.3327
# Epoch 304/3500, Training Loss: 1.2021
# Val. confidence score: 0.0202, Val. loss: 0.9752, Avg. Uncertainty: 0.3134
# Epoch 305/3500, Training Loss: 1.2004
# Val. confidence score: 0.0069, Val. loss: 0.9679, Avg. Uncertainty: 0.3197
# Epoch 306/3500, Training Loss: 1.1757
# Val. confidence score: -0.0255, Val. loss: 1.0209, Avg. Uncertainty: 0.3244
# Epoch 307/3500, Training Loss: 1.0822
# Val. confidence score: -0.0034, Val. loss: 1.0029, Avg. Uncertainty: 0.3500
# Epoch 308/3500, Training Loss: 1.1368
# Val. confidence score: -0.0239, Val. loss: 1.0079, Avg. Uncertainty: 0.3271
# Epoch 309/3500, Training Loss: 1.1593
# Val. confidence score: 0.0015, Val. loss: 0.9769, Avg. Uncertainty: 0.3297
# Epoch 310/3500, Training Loss: 1.2022
# Val. confidence score: -0.0019, Val. loss: 1.0065, Avg. Uncertainty: 0.3366
# Epoch 311/3500, Training Loss: 1.0117
# Val. confidence score: 0.0274, Val. loss: 0.9962, Avg. Uncertainty: 0.3117
# Epoch 312/3500, Training Loss: 1.0999
# Val. confidence score: 0.0161, Val. loss: 0.9722, Avg. Uncertainty: 0.3374
# Epoch 313/3500, Training Loss: 1.1228
# Val. confidence score: 0.0046, Val. loss: 0.9939, Avg. Uncertainty: 0.2965
# Epoch 314/3500, Training Loss: 1.1191
# Val. confidence score: 0.0211, Val. loss: 0.9799, Avg. Uncertainty: 0.3432
# Epoch 315/3500, Training Loss: 1.1307
# Val. confidence score: 0.0302, Val. loss: 0.9789, Avg. Uncertainty: 0.3157
# Epoch 316/3500, Training Loss: 1.0560
# Val. confidence score: -0.0012, Val. loss: 0.9771, Avg. Uncertainty: 0.3333
# Epoch 317/3500, Training Loss: 1.1780
# Val. confidence score: -0.0411, Val. loss: 1.0083, Avg. Uncertainty: 0.3380
# Epoch 318/3500, Training Loss: 1.0826
# Val. confidence score: 0.0408, Val. loss: 0.9738, Avg. Uncertainty: 0.3105
# Epoch 319/3500, Training Loss: 1.1356
# Val. confidence score: 0.0286, Val. loss: 1.0021, Avg. Uncertainty: 0.3121
# Epoch 320/3500, Training Loss: 1.2613
# Val. confidence score: 0.0292, Val. loss: 1.0071, Avg. Uncertainty: 0.3113
# Epoch 321/3500, Training Loss: 1.1873
# Val. confidence score: 0.0375, Val. loss: 0.9711, Avg. Uncertainty: 0.3204
# Epoch 322/3500, Training Loss: 1.1727
# Val. confidence score: 0.0220, Val. loss: 1.0076, Avg. Uncertainty: 0.3161
# Epoch 323/3500, Training Loss: 1.0397
# Val. confidence score: 0.0233, Val. loss: 0.9776, Avg. Uncertainty: 0.3117
# Epoch 324/3500, Training Loss: 1.1211
# Val. confidence score: 0.0087, Val. loss: 0.9944, Avg. Uncertainty: 0.3209
# Epoch 325/3500, Training Loss: 1.1947
# Val. confidence score: -0.0049, Val. loss: 0.9931, Avg. Uncertainty: 0.3130
# Epoch 326/3500, Training Loss: 1.0748
# Val. confidence score: 0.0689, Val. loss: 0.9853, Avg. Uncertainty: 0.3182
# Epoch 327/3500, Training Loss: 1.1555
# Val. confidence score: 0.0062, Val. loss: 0.9824, Avg. Uncertainty: 0.3401
# Epoch 328/3500, Training Loss: 1.3881
# Val. confidence score: -0.0137, Val. loss: 0.9919, Avg. Uncertainty: 0.3062
# Epoch 329/3500, Training Loss: 1.1816
# Val. confidence score: -0.0416, Val. loss: 1.0044, Avg. Uncertainty: 0.2979
# Epoch 330/3500, Training Loss: 1.0914
# Val. confidence score: -0.0230, Val. loss: 1.0100, Avg. Uncertainty: 0.2859
# Epoch 331/3500, Training Loss: 1.0931
# Val. confidence score: -0.0320, Val. loss: 0.9944, Avg. Uncertainty: 0.3074
# Epoch 332/3500, Training Loss: 1.0980
# Val. confidence score: 0.0314, Val. loss: 1.0095, Avg. Uncertainty: 0.3261
# Epoch 333/3500, Training Loss: 1.1587
# Val. confidence score: 0.0129, Val. loss: 0.9925, Avg. Uncertainty: 0.3017
# Epoch 334/3500, Training Loss: 1.0169
# Val. confidence score: 0.0173, Val. loss: 1.0002, Avg. Uncertainty: 0.3127
# Epoch 335/3500, Training Loss: 1.0773
# Val. confidence score: 0.0145, Val. loss: 0.9939, Avg. Uncertainty: 0.2940
# Epoch 336/3500, Training Loss: 0.9833
# Val. confidence score: -0.0009, Val. loss: 1.0001, Avg. Uncertainty: 0.2772
# Epoch 337/3500, Training Loss: 1.2216
# Val. confidence score: 0.0262, Val. loss: 0.9754, Avg. Uncertainty: 0.3046
# Epoch 338/3500, Training Loss: 1.0571
# Val. confidence score: 0.0307, Val. loss: 0.9823, Avg. Uncertainty: 0.3098
# Epoch 339/3500, Training Loss: 1.1461
# Val. confidence score: 0.0485, Val. loss: 0.9699, Avg. Uncertainty: 0.3209
# Epoch 340/3500, Training Loss: 1.1303
# Val. confidence score: 0.0311, Val. loss: 0.9890, Avg. Uncertainty: 0.3258
# Epoch 341/3500, Training Loss: 1.0292
# Val. confidence score: 0.0408, Val. loss: 1.0075, Avg. Uncertainty: 0.3174
# Epoch 342/3500, Training Loss: 1.0452
# Val. confidence score: 0.0168, Val. loss: 0.9833, Avg. Uncertainty: 0.2955
# Epoch 343/3500, Training Loss: 1.0882
# Val. confidence score: 0.0496, Val. loss: 0.9649, Avg. Uncertainty: 0.2882
# Epoch 344/3500, Training Loss: 1.0566
# Val. confidence score: 0.0323, Val. loss: 0.9883, Avg. Uncertainty: 0.3078
# Epoch 345/3500, Training Loss: 1.1706
# Val. confidence score: 0.0592, Val. loss: 0.9636, Avg. Uncertainty: 0.2911
# Epoch 346/3500, Training Loss: 1.2047
# Val. confidence score: 0.0199, Val. loss: 1.0022, Avg. Uncertainty: 0.2957
# Epoch 347/3500, Training Loss: 1.2261
# Val. confidence score: 0.0481, Val. loss: 0.9640, Avg. Uncertainty: 0.2946
# Epoch 348/3500, Training Loss: 1.1186
# Val. confidence score: 0.0387, Val. loss: 0.9832, Avg. Uncertainty: 0.3136
# Epoch 349/3500, Training Loss: 1.1350
# Val. confidence score: 0.0239, Val. loss: 0.9712, Avg. Uncertainty: 0.3081
# Epoch 350/3500, Training Loss: 1.2037
# Val. confidence score: 0.0022, Val. loss: 0.9908, Avg. Uncertainty: 0.2883
# Epoch 351/3500, Training Loss: 1.0714
# Val. confidence score: -0.0081, Val. loss: 1.0009, Avg. Uncertainty: 0.2889
# Epoch 352/3500, Training Loss: 0.9548
# Val. confidence score: 0.0397, Val. loss: 0.9795, Avg. Uncertainty: 0.2829
# Epoch 353/3500, Training Loss: 1.0479
# Val. confidence score: 0.0247, Val. loss: 0.9805, Avg. Uncertainty: 0.2915
# Epoch 354/3500, Training Loss: 1.0915
# Val. confidence score: 0.0250, Val. loss: 0.9916, Avg. Uncertainty: 0.2903
# Epoch 355/3500, Training Loss: 0.9890
# Val. confidence score: 0.0208, Val. loss: 0.9886, Avg. Uncertainty: 0.3002
# Epoch 356/3500, Training Loss: 1.1050
# Val. confidence score: 0.0043, Val. loss: 0.9865, Avg. Uncertainty: 0.2971
# Epoch 357/3500, Training Loss: 1.1243
# Val. confidence score: -0.0071, Val. loss: 1.0066, Avg. Uncertainty: 0.2894
# Epoch 358/3500, Training Loss: 1.0312
# Val. confidence score: 0.0126, Val. loss: 0.9981, Avg. Uncertainty: 0.3032
# Epoch 359/3500, Training Loss: 1.0787
# Val. confidence score: -0.0105, Val. loss: 1.0018, Avg. Uncertainty: 0.2897
# Epoch 360/3500, Training Loss: 1.1178
# Val. confidence score: 0.0397, Val. loss: 0.9798, Avg. Uncertainty: 0.3022
# Epoch 361/3500, Training Loss: 1.1711
# Val. confidence score: 0.0135, Val. loss: 0.9823, Avg. Uncertainty: 0.2820
# Epoch 362/3500, Training Loss: 1.1062
# Val. confidence score: 0.0091, Val. loss: 0.9917, Avg. Uncertainty: 0.3145
# Epoch 363/3500, Training Loss: 1.1117
# Val. confidence score: 0.0479, Val. loss: 0.9840, Avg. Uncertainty: 0.2894
# Epoch 364/3500, Training Loss: 0.9676
# Val. confidence score: -0.0231, Val. loss: 0.9984, Avg. Uncertainty: 0.3082
# Epoch 365/3500, Training Loss: 1.0847
# Val. confidence score: -0.0132, Val. loss: 1.0061, Avg. Uncertainty: 0.2939
# Epoch 366/3500, Training Loss: 1.0162
# Val. confidence score: 0.0577, Val. loss: 0.9840, Avg. Uncertainty: 0.2813
# Epoch 367/3500, Training Loss: 1.0037
# Val. confidence score: 0.0103, Val. loss: 0.9722, Avg. Uncertainty: 0.2857
# Epoch 368/3500, Training Loss: 0.9555
# Val. confidence score: 0.0613, Val. loss: 0.9836, Avg. Uncertainty: 0.2655
# Epoch 369/3500, Training Loss: 1.1120
# Val. confidence score: 0.0321, Val. loss: 0.9899, Avg. Uncertainty: 0.2726
# Epoch 370/3500, Training Loss: 1.1109
# Val. confidence score: 0.0306, Val. loss: 1.0056, Avg. Uncertainty: 0.2436
# Epoch 371/3500, Training Loss: 1.1031
# Val. confidence score: 0.0086, Val. loss: 0.9994, Avg. Uncertainty: 0.2876
# Epoch 372/3500, Training Loss: 1.0134
# Val. confidence score: 0.0064, Val. loss: 0.9840, Avg. Uncertainty: 0.2819
# Epoch 373/3500, Training Loss: 1.0557
# Val. confidence score: 0.0150, Val. loss: 0.9905, Avg. Uncertainty: 0.2747
# Epoch 374/3500, Training Loss: 1.0505
# Val. confidence score: 0.0209, Val. loss: 0.9930, Avg. Uncertainty: 0.2688
# Epoch 375/3500, Training Loss: 1.0752
# Val. confidence score: 0.0337, Val. loss: 0.9877, Avg. Uncertainty: 0.2959
# Epoch 376/3500, Training Loss: 1.2476
# Val. confidence score: 0.0005, Val. loss: 0.9991, Avg. Uncertainty: 0.2894
# Epoch 377/3500, Training Loss: 0.9031
# Val. confidence score: 0.0073, Val. loss: 0.9918, Avg. Uncertainty: 0.2815
# Epoch 378/3500, Training Loss: 0.9538
# Val. confidence score: 0.0271, Val. loss: 0.9933, Avg. Uncertainty: 0.2756
# Epoch 379/3500, Training Loss: 0.9684
# Val. confidence score: 0.0231, Val. loss: 0.9946, Avg. Uncertainty: 0.2583
# Epoch 380/3500, Training Loss: 0.9885
# Val. confidence score: 0.0406, Val. loss: 0.9810, Avg. Uncertainty: 0.2741
# Epoch 381/3500, Training Loss: 1.1081
# Val. confidence score: -0.0099, Val. loss: 1.0088, Avg. Uncertainty: 0.2933
# Epoch 382/3500, Training Loss: 0.9781
# Val. confidence score: 0.0194, Val. loss: 0.9848, Avg. Uncertainty: 0.2913
# Epoch 383/3500, Training Loss: 1.0631
# Val. confidence score: 0.0415, Val. loss: 0.9817, Avg. Uncertainty: 0.2800
# Epoch 384/3500, Training Loss: 1.0330
# Val. confidence score: 0.0364, Val. loss: 0.9861, Avg. Uncertainty: 0.2414
# Epoch 385/3500, Training Loss: 1.0637
# Val. confidence score: 0.0070, Val. loss: 0.9918, Avg. Uncertainty: 0.2433
# Epoch 386/3500, Training Loss: 0.9828
# Val. confidence score: 0.0647, Val. loss: 0.9713, Avg. Uncertainty: 0.2583
# Epoch 387/3500, Training Loss: 1.0333
# Val. confidence score: 0.0165, Val. loss: 0.9862, Avg. Uncertainty: 0.2935
# Epoch 388/3500, Training Loss: 1.1070
# Val. confidence score: 0.0039, Val. loss: 0.9816, Avg. Uncertainty: 0.2807
# Epoch 389/3500, Training Loss: 1.0011
# Val. confidence score: 0.0125, Val. loss: 0.9754, Avg. Uncertainty: 0.2841
# Epoch 390/3500, Training Loss: 1.0180
# Val. confidence score: 0.0093, Val. loss: 0.9897, Avg. Uncertainty: 0.2834
# Epoch 391/3500, Training Loss: 0.9907
# Val. confidence score: 0.0317, Val. loss: 0.9741, Avg. Uncertainty: 0.2587
# Epoch 392/3500, Training Loss: 1.0374
# Val. confidence score: -0.0026, Val. loss: 1.0041, Avg. Uncertainty: 0.2728
# Epoch 393/3500, Training Loss: 0.9430
# Val. confidence score: 0.0294, Val. loss: 0.9831, Avg. Uncertainty: 0.2629
# Epoch 394/3500, Training Loss: 0.9837
# Val. confidence score: 0.0177, Val. loss: 1.0047, Avg. Uncertainty: 0.2409
# Epoch 395/3500, Training Loss: 0.9168
# Val. confidence score: 0.0084, Val. loss: 0.9981, Avg. Uncertainty: 0.2697
# Epoch 396/3500, Training Loss: 0.9901
# Val. confidence score: 0.0177, Val. loss: 0.9938, Avg. Uncertainty: 0.2336
# Epoch 397/3500, Training Loss: 1.0428
# Val. confidence score: 0.0639, Val. loss: 0.9661, Avg. Uncertainty: 0.2544
# Epoch 398/3500, Training Loss: 1.0100
# Val. confidence score: 0.0131, Val. loss: 0.9884, Avg. Uncertainty: 0.2474
# Epoch 399/3500, Training Loss: 0.9697
# Val. confidence score: 0.0244, Val. loss: 0.9861, Avg. Uncertainty: 0.2597
# Epoch 400/3500, Training Loss: 0.9412
# Val. confidence score: 0.0533, Val. loss: 0.9706, Avg. Uncertainty: 0.2654
# Epoch 401/3500, Training Loss: 0.9067
# Val. confidence score: -0.0154, Val. loss: 0.9868, Avg. Uncertainty: 0.2513
# Epoch 402/3500, Training Loss: 1.0235
# Val. confidence score: 0.0419, Val. loss: 0.9728, Avg. Uncertainty: 0.2655
# Epoch 403/3500, Training Loss: 1.0467
# Val. confidence score: 0.0277, Val. loss: 0.9814, Avg. Uncertainty: 0.2724
# Epoch 404/3500, Training Loss: 0.9965
# Val. confidence score: 0.0411, Val. loss: 0.9815, Avg. Uncertainty: 0.2590
# Epoch 405/3500, Training Loss: 1.0535
# Val. confidence score: 0.0241, Val. loss: 0.9905, Avg. Uncertainty: 0.2671
# Epoch 406/3500, Training Loss: 1.0031
# Val. confidence score: 0.0079, Val. loss: 0.9888, Avg. Uncertainty: 0.2784
# Epoch 407/3500, Training Loss: 0.9887
# Val. confidence score: -0.0133, Val. loss: 0.9993, Avg. Uncertainty: 0.2793
# Epoch 408/3500, Training Loss: 1.0840
# Val. confidence score: -0.0078, Val. loss: 0.9991, Avg. Uncertainty: 0.2511
# Epoch 409/3500, Training Loss: 1.0236
# Val. confidence score: 0.0391, Val. loss: 0.9752, Avg. Uncertainty: 0.2586
# Epoch 410/3500, Training Loss: 1.0141
# Val. confidence score: 0.0350, Val. loss: 0.9843, Avg. Uncertainty: 0.2586
# Epoch 411/3500, Training Loss: 0.9749
# Val. confidence score: 0.0322, Val. loss: 0.9798, Avg. Uncertainty: 0.2517
# Epoch 412/3500, Training Loss: 1.0022
# Val. confidence score: 0.0398, Val. loss: 0.9729, Avg. Uncertainty: 0.2568
# Epoch 413/3500, Training Loss: 1.0476
# Val. confidence score: 0.0344, Val. loss: 0.9843, Avg. Uncertainty: 0.2528
# Epoch 414/3500, Training Loss: 0.9739
# Val. confidence score: 0.0432, Val. loss: 0.9841, Avg. Uncertainty: 0.2401
# Epoch 415/3500, Training Loss: 0.9983
# Val. confidence score: 0.0533, Val. loss: 0.9570, Avg. Uncertainty: 0.2623
# Epoch 416/3500, Training Loss: 1.0558
# Val. confidence score: 0.0135, Val. loss: 0.9845, Avg. Uncertainty: 0.2455
# Epoch 417/3500, Training Loss: 1.0712
# Val. confidence score: 0.0023, Val. loss: 0.9757, Avg. Uncertainty: 0.2707
# Epoch 418/3500, Training Loss: 0.9683
# Val. confidence score: 0.0748, Val. loss: 0.9680, Avg. Uncertainty: 0.2570
# Epoch 419/3500, Training Loss: 0.9839
# Val. confidence score: 0.0231, Val. loss: 0.9812, Avg. Uncertainty: 0.2349
# Epoch 420/3500, Training Loss: 0.9643
# Val. confidence score: 0.0249, Val. loss: 0.9935, Avg. Uncertainty: 0.2417
# Epoch 421/3500, Training Loss: 1.1583
# Val. confidence score: 0.0485, Val. loss: 0.9789, Avg. Uncertainty: 0.2333
# Epoch 422/3500, Training Loss: 1.0401
# Val. confidence score: 0.0080, Val. loss: 0.9907, Avg. Uncertainty: 0.2383
# Epoch 423/3500, Training Loss: 1.0152
# Val. confidence score: -0.0155, Val. loss: 1.0023, Avg. Uncertainty: 0.2476
# Epoch 424/3500, Training Loss: 0.9242
# Val. confidence score: 0.0483, Val. loss: 0.9710, Avg. Uncertainty: 0.2330
# ...
# Epoch 3361/3500, Training Loss: 0.2754
# Val. confidence score: 0.7642, Val. loss: 0.3645, Avg. Uncertainty: 0.1183
# Epoch 3362/3500, Training Loss: 0.2691
# Val. confidence score: 0.7694, Val. loss: 0.3602, Avg. Uncertainty: 0.1109
# Epoch 3363/3500, Training Loss: 0.2622
# Val. confidence score: 0.7473, Val. loss: 0.3710, Avg. Uncertainty: 0.1128
# Epoch 3364/3500, Training Loss: 0.2603
# Val. confidence score: 0.7593, Val. loss: 0.3637, Avg. Uncertainty: 0.1127
# Epoch 3365/3500, Training Loss: 0.2846
# Val. confidence score: 0.7592, Val. loss: 0.3644, Avg. Uncertainty: 0.1091
# Epoch 3366/3500, Training Loss: 0.2926
# Val. confidence score: 0.7638, Val. loss: 0.3661, Avg. Uncertainty: 0.1035
# Epoch 3367/3500, Training Loss: 0.2809
# Val. confidence score: 0.7704, Val. loss: 0.3582, Avg. Uncertainty: 0.1076
# Epoch 3368/3500, Training Loss: 0.2776
# Val. confidence score: 0.7568, Val. loss: 0.3643, Avg. Uncertainty: 0.1109
# Epoch 3369/3500, Training Loss: 0.2776
# Val. confidence score: 0.7602, Val. loss: 0.3653, Avg. Uncertainty: 0.1022
# Epoch 3370/3500, Training Loss: 0.2694
# Val. confidence score: 0.7649, Val. loss: 0.3588, Avg. Uncertainty: 0.0987
# Epoch 3371/3500, Training Loss: 0.2582
# Val. confidence score: 0.7575, Val. loss: 0.3654, Avg. Uncertainty: 0.1065
# Epoch 3372/3500, Training Loss: 0.3043
# Val. confidence score: 0.7625, Val. loss: 0.3574, Avg. Uncertainty: 0.1034
# Epoch 3373/3500, Training Loss: 0.3038
# Val. confidence score: 0.7637, Val. loss: 0.3606, Avg. Uncertainty: 0.1060
# Epoch 3374/3500, Training Loss: 0.2476
# Val. confidence score: 0.7693, Val. loss: 0.3593, Avg. Uncertainty: 0.1069
# Epoch 3375/3500, Training Loss: 0.2770
# Val. confidence score: 0.7638, Val. loss: 0.3607, Avg. Uncertainty: 0.1179
# Epoch 3376/3500, Training Loss: 0.2893
# Val. confidence score: 0.7679, Val. loss: 0.3586, Avg. Uncertainty: 0.1046
# Epoch 3377/3500, Training Loss: 0.2974
# Val. confidence score: 0.7701, Val. loss: 0.3600, Avg. Uncertainty: 0.1009
# Epoch 3378/3500, Training Loss: 0.2686
# Val. confidence score: 0.7701, Val. loss: 0.3585, Avg. Uncertainty: 0.1056
# Epoch 3379/3500, Training Loss: 0.2614
# Val. confidence score: 0.7743, Val. loss: 0.3621, Avg. Uncertainty: 0.1026
# Epoch 3380/3500, Training Loss: 0.2610
# Val. confidence score: 0.7689, Val. loss: 0.3555, Avg. Uncertainty: 0.1060
# Epoch 3381/3500, Training Loss: 0.2915
# Val. confidence score: 0.7641, Val. loss: 0.3666, Avg. Uncertainty: 0.1079
# Epoch 3382/3500, Training Loss: 0.2356
# Val. confidence score: 0.7720, Val. loss: 0.3569, Avg. Uncertainty: 0.1140
# Epoch 3383/3500, Training Loss: 0.2758
# Val. confidence score: 0.7621, Val. loss: 0.3616, Avg. Uncertainty: 0.1115
# Epoch 3384/3500, Training Loss: 0.2819
# Val. confidence score: 0.7633, Val. loss: 0.3624, Avg. Uncertainty: 0.1138
# Epoch 3385/3500, Training Loss: 0.2570
# Val. confidence score: 0.7748, Val. loss: 0.3578, Avg. Uncertainty: 0.1143
# Epoch 3386/3500, Training Loss: 0.2740
# Val. confidence score: 0.7713, Val. loss: 0.3590, Avg. Uncertainty: 0.1061
# Epoch 3387/3500, Training Loss: 0.2562
# Val. confidence score: 0.7724, Val. loss: 0.3594, Avg. Uncertainty: 0.1042
# Epoch 3388/3500, Training Loss: 0.2922
# Val. confidence score: 0.7702, Val. loss: 0.3592, Avg. Uncertainty: 0.1136
# Epoch 3389/3500, Training Loss: 0.2486
# Val. confidence score: 0.7627, Val. loss: 0.3618, Avg. Uncertainty: 0.1138
# Epoch 3390/3500, Training Loss: 0.2879
# Val. confidence score: 0.7682, Val. loss: 0.3619, Avg. Uncertainty: 0.1077
# Epoch 3391/3500, Training Loss: 0.3196
# Val. confidence score: 0.7668, Val. loss: 0.3629, Avg. Uncertainty: 0.1159
# Epoch 3392/3500, Training Loss: 0.2691
# Val. confidence score: 0.7773, Val. loss: 0.3574, Avg. Uncertainty: 0.1056
# Epoch 3393/3500, Training Loss: 0.2641
# Val. confidence score: 0.7666, Val. loss: 0.3587, Avg. Uncertainty: 0.1081
# Epoch 3394/3500, Training Loss: 0.2789
# Val. confidence score: 0.7651, Val. loss: 0.3614, Avg. Uncertainty: 0.0969
# Epoch 3395/3500, Training Loss: 0.2785
# Val. confidence score: 0.7752, Val. loss: 0.3573, Avg. Uncertainty: 0.1034
# Epoch 3396/3500, Training Loss: 0.2763
# Val. confidence score: 0.7740, Val. loss: 0.3585, Avg. Uncertainty: 0.1024
# Epoch 3397/3500, Training Loss: 0.2605
# Val. confidence score: 0.7638, Val. loss: 0.3645, Avg. Uncertainty: 0.1060
# Epoch 3398/3500, Training Loss: 0.2984
# Val. confidence score: 0.7611, Val. loss: 0.3723, Avg. Uncertainty: 0.1130
# Epoch 3399/3500, Training Loss: 0.2903
# Val. confidence score: 0.7647, Val. loss: 0.3619, Avg. Uncertainty: 0.1148
# Epoch 3400/3500, Training Loss: 0.2641
# Val. confidence score: 0.7599, Val. loss: 0.3680, Avg. Uncertainty: 0.1138
# Epoch 3401/3500, Training Loss: 0.2606
# Val. confidence score: 0.7608, Val. loss: 0.3667, Avg. Uncertainty: 0.1130
# Epoch 3402/3500, Training Loss: 0.2749
# Val. confidence score: 0.7726, Val. loss: 0.3551, Avg. Uncertainty: 0.1127
# Epoch 3403/3500, Training Loss: 0.2764
# Val. confidence score: 0.7616, Val. loss: 0.3640, Avg. Uncertainty: 0.1087
# Epoch 3404/3500, Training Loss: 0.2835
# Val. confidence score: 0.7697, Val. loss: 0.3623, Avg. Uncertainty: 0.1159
# Epoch 3405/3500, Training Loss: 0.2645
# Val. confidence score: 0.7663, Val. loss: 0.3609, Avg. Uncertainty: 0.1096
# Epoch 3406/3500, Training Loss: 0.2412
# Val. confidence score: 0.7749, Val. loss: 0.3583, Avg. Uncertainty: 0.1010
# Epoch 3407/3500, Training Loss: 0.2509
# Val. confidence score: 0.7718, Val. loss: 0.3555, Avg. Uncertainty: 0.1035
# Epoch 3408/3500, Training Loss: 0.2865
# Val. confidence score: 0.7767, Val. loss: 0.3574, Avg. Uncertainty: 0.0961
# Epoch 3409/3500, Training Loss: 0.2897
# Val. confidence score: 0.7737, Val. loss: 0.3539, Avg. Uncertainty: 0.1064
# Epoch 3410/3500, Training Loss: 0.2999
# Val. confidence score: 0.7752, Val. loss: 0.3579, Avg. Uncertainty: 0.1046
# Epoch 3411/3500, Training Loss: 0.2933
# Val. confidence score: 0.7720, Val. loss: 0.3593, Avg. Uncertainty: 0.1045
# Epoch 3412/3500, Training Loss: 0.2791
# Val. confidence score: 0.7741, Val. loss: 0.3600, Avg. Uncertainty: 0.1137
# Epoch 3413/3500, Training Loss: 0.3031
# Val. confidence score: 0.7686, Val. loss: 0.3578, Avg. Uncertainty: 0.1042
# Epoch 3414/3500, Training Loss: 0.2560
# Val. confidence score: 0.7636, Val. loss: 0.3595, Avg. Uncertainty: 0.1116
# Epoch 3415/3500, Training Loss: 0.2791
# Val. confidence score: 0.7571, Val. loss: 0.3601, Avg. Uncertainty: 0.1064
# Epoch 3416/3500, Training Loss: 0.2599
# Val. confidence score: 0.7673, Val. loss: 0.3564, Avg. Uncertainty: 0.1056
# Epoch 3417/3500, Training Loss: 0.2607
# Val. confidence score: 0.7747, Val. loss: 0.3549, Avg. Uncertainty: 0.1005
# Epoch 3418/3500, Training Loss: 0.2657
# Val. confidence score: 0.7693, Val. loss: 0.3595, Avg. Uncertainty: 0.1093
# Epoch 3419/3500, Training Loss: 0.2814
# Val. confidence score: 0.7654, Val. loss: 0.3618, Avg. Uncertainty: 0.1056
# Epoch 3420/3500, Training Loss: 0.2361
# Val. confidence score: 0.7728, Val. loss: 0.3570, Avg. Uncertainty: 0.1014
# Epoch 3421/3500, Training Loss: 0.2870
# Val. confidence score: 0.7771, Val. loss: 0.3577, Avg. Uncertainty: 0.1058
# Epoch 3422/3500, Training Loss: 0.2753
# Val. confidence score: 0.7728, Val. loss: 0.3563, Avg. Uncertainty: 0.1039
# Epoch 3423/3500, Training Loss: 0.2550
# Val. confidence score: 0.7625, Val. loss: 0.3655, Avg. Uncertainty: 0.0990
# Epoch 3424/3500, Training Loss: 0.2889
# Val. confidence score: 0.7686, Val. loss: 0.3574, Avg. Uncertainty: 0.1042
# Epoch 3425/3500, Training Loss: 0.2788
# Val. confidence score: 0.7631, Val. loss: 0.3620, Avg. Uncertainty: 0.1022
# Epoch 3426/3500, Training Loss: 0.2992
# Val. confidence score: 0.7631, Val. loss: 0.3587, Avg. Uncertainty: 0.1022
# Epoch 3427/3500, Training Loss: 0.2744
# Val. confidence score: 0.7689, Val. loss: 0.3645, Avg. Uncertainty: 0.1143
# Epoch 3428/3500, Training Loss: 0.2765
# Val. confidence score: 0.7702, Val. loss: 0.3607, Avg. Uncertainty: 0.1059
# Epoch 3429/3500, Training Loss: 0.2552
# Val. confidence score: 0.7718, Val. loss: 0.3558, Avg. Uncertainty: 0.1044
# Epoch 3430/3500, Training Loss: 0.2874
# Val. confidence score: 0.7753, Val. loss: 0.3601, Avg. Uncertainty: 0.1080
# Epoch 3431/3500, Training Loss: 0.2870
# Val. confidence score: 0.7751, Val. loss: 0.3605, Avg. Uncertainty: 0.1022
# Epoch 3432/3500, Training Loss: 0.2585
# Val. confidence score: 0.7737, Val. loss: 0.3603, Avg. Uncertainty: 0.1029
# Epoch 3433/3500, Training Loss: 0.2860
# Val. confidence score: 0.7754, Val. loss: 0.3554, Avg. Uncertainty: 0.1054
# Epoch 3434/3500, Training Loss: 0.2597
# Val. confidence score: 0.7736, Val. loss: 0.3576, Avg. Uncertainty: 0.1034
# Epoch 3435/3500, Training Loss: 0.2625
# Val. confidence score: 0.7672, Val. loss: 0.3656, Avg. Uncertainty: 0.1104
# Epoch 3436/3500, Training Loss: 0.2549
# Val. confidence score: 0.7768, Val. loss: 0.3593, Avg. Uncertainty: 0.1040
# Epoch 3437/3500, Training Loss: 0.2889
# Val. confidence score: 0.7667, Val. loss: 0.3609, Avg. Uncertainty: 0.1110
# Epoch 3438/3500, Training Loss: 0.2668
# Val. confidence score: 0.7745, Val. loss: 0.3564, Avg. Uncertainty: 0.1134
# Epoch 3439/3500, Training Loss: 0.3242
# Val. confidence score: 0.7752, Val. loss: 0.3554, Avg. Uncertainty: 0.1045
# Epoch 3440/3500, Training Loss: 0.3070
# Val. confidence score: 0.7811, Val. loss: 0.3546, Avg. Uncertainty: 0.1183
# Epoch 3441/3500, Training Loss: 0.2700
# Val. confidence score: 0.7787, Val. loss: 0.3525, Avg. Uncertainty: 0.1045
# Epoch 3442/3500, Training Loss: 0.2764
# Val. confidence score: 0.7741, Val. loss: 0.3600, Avg. Uncertainty: 0.1026
# Epoch 3443/3500, Training Loss: 0.2629
# Val. confidence score: 0.7803, Val. loss: 0.3534, Avg. Uncertainty: 0.1104
# Epoch 3444/3500, Training Loss: 0.3016
# Val. confidence score: 0.7661, Val. loss: 0.3602, Avg. Uncertainty: 0.1122
# Epoch 3445/3500, Training Loss: 0.2704
# Val. confidence score: 0.7711, Val. loss: 0.3673, Avg. Uncertainty: 0.1108
# Epoch 3446/3500, Training Loss: 0.2731
# Val. confidence score: 0.7709, Val. loss: 0.3619, Avg. Uncertainty: 0.1150
# Epoch 3447/3500, Training Loss: 0.2700
# Val. confidence score: 0.7711, Val. loss: 0.3581, Avg. Uncertainty: 0.1067
# Epoch 3448/3500, Training Loss: 0.2959
# Val. confidence score: 0.7809, Val. loss: 0.3564, Avg. Uncertainty: 0.1166
# Epoch 3449/3500, Training Loss: 0.2978
# Val. confidence score: 0.7638, Val. loss: 0.3611, Avg. Uncertainty: 0.1146
# Epoch 3450/3500, Training Loss: 0.2800
# Val. confidence score: 0.7558, Val. loss: 0.3630, Avg. Uncertainty: 0.1113
# Epoch 3451/3500, Training Loss: 0.2770
# Val. confidence score: 0.7693, Val. loss: 0.3560, Avg. Uncertainty: 0.1048
# Epoch 3452/3500, Training Loss: 0.3004
# Val. confidence score: 0.7696, Val. loss: 0.3575, Avg. Uncertainty: 0.1053
# Epoch 3453/3500, Training Loss: 0.2744
# Val. confidence score: 0.7661, Val. loss: 0.3588, Avg. Uncertainty: 0.1007
# Epoch 3454/3500, Training Loss: 0.2575
# Val. confidence score: 0.7630, Val. loss: 0.3605, Avg. Uncertainty: 0.0958
# Epoch 3455/3500, Training Loss: 0.2693
# Val. confidence score: 0.7679, Val. loss: 0.3587, Avg. Uncertainty: 0.0979
# Epoch 3456/3500, Training Loss: 0.2725
# Val. confidence score: 0.7740, Val. loss: 0.3550, Avg. Uncertainty: 0.1049
# Epoch 3457/3500, Training Loss: 0.2737
# Val. confidence score: 0.7766, Val. loss: 0.3545, Avg. Uncertainty: 0.1068
# Epoch 3458/3500, Training Loss: 0.2622
# Val. confidence score: 0.7641, Val. loss: 0.3618, Avg. Uncertainty: 0.1081
# Epoch 3459/3500, Training Loss: 0.2986
# Val. confidence score: 0.7744, Val. loss: 0.3575, Avg. Uncertainty: 0.1077
# Epoch 3460/3500, Training Loss: 0.2814
# Val. confidence score: 0.7701, Val. loss: 0.3567, Avg. Uncertainty: 0.1072
# Epoch 3461/3500, Training Loss: 0.2708
# Val. confidence score: 0.7762, Val. loss: 0.3528, Avg. Uncertainty: 0.1077
# Epoch 3462/3500, Training Loss: 0.2799
# Val. confidence score: 0.7771, Val. loss: 0.3580, Avg. Uncertainty: 0.1024
# Epoch 3463/3500, Training Loss: 0.2693
# Val. confidence score: 0.7716, Val. loss: 0.3542, Avg. Uncertainty: 0.1086
# Epoch 3464/3500, Training Loss: 0.2713
# Val. confidence score: 0.7779, Val. loss: 0.3566, Avg. Uncertainty: 0.1099
# Epoch 3465/3500, Training Loss: 0.2622
# Val. confidence score: 0.7702, Val. loss: 0.3571, Avg. Uncertainty: 0.1108
# Epoch 3466/3500, Training Loss: 0.2620
# Val. confidence score: 0.7808, Val. loss: 0.3548, Avg. Uncertainty: 0.1062
# Epoch 3467/3500, Training Loss: 0.2788
# Val. confidence score: 0.7739, Val. loss: 0.3554, Avg. Uncertainty: 0.1112
# Epoch 3468/3500, Training Loss: 0.3099
# Val. confidence score: 0.7709, Val. loss: 0.3636, Avg. Uncertainty: 0.1122
# Epoch 3469/3500, Training Loss: 0.2506
# Val. confidence score: 0.7644, Val. loss: 0.3671, Avg. Uncertainty: 0.1195
# Epoch 3470/3500, Training Loss: 0.2958
# Val. confidence score: 0.7693, Val. loss: 0.3597, Avg. Uncertainty: 0.1048
# Epoch 3471/3500, Training Loss: 0.2861
# Val. confidence score: 0.7688, Val. loss: 0.3580, Avg. Uncertainty: 0.1002
# Epoch 3472/3500, Training Loss: 0.2674
# Val. confidence score: 0.7738, Val. loss: 0.3605, Avg. Uncertainty: 0.1076
# Epoch 3473/3500, Training Loss: 0.2934
# Val. confidence score: 0.7661, Val. loss: 0.3599, Avg. Uncertainty: 0.1096
# Epoch 3474/3500, Training Loss: 0.2837
# Val. confidence score: 0.7676, Val. loss: 0.3643, Avg. Uncertainty: 0.1096
# Epoch 3475/3500, Training Loss: 0.2888
# Val. confidence score: 0.7722, Val. loss: 0.3615, Avg. Uncertainty: 0.1126
# Epoch 3476/3500, Training Loss: 0.2693
# Val. confidence score: 0.7802, Val. loss: 0.3540, Avg. Uncertainty: 0.1017
# Epoch 3477/3500, Training Loss: 0.2869
# Val. confidence score: 0.7774, Val. loss: 0.3543, Avg. Uncertainty: 0.1067
# Epoch 3478/3500, Training Loss: 0.2791
# Val. confidence score: 0.7800, Val. loss: 0.3548, Avg. Uncertainty: 0.1106
# Epoch 3479/3500, Training Loss: 0.2962
# Val. confidence score: 0.7734, Val. loss: 0.3539, Avg. Uncertainty: 0.1054
# Epoch 3480/3500, Training Loss: 0.2363
# Val. confidence score: 0.7800, Val. loss: 0.3549, Avg. Uncertainty: 0.1022
# Epoch 3481/3500, Training Loss: 0.2777
# Val. confidence score: 0.7742, Val. loss: 0.3553, Avg. Uncertainty: 0.1043
# Epoch 3482/3500, Training Loss: 0.2372
# Val. confidence score: 0.7740, Val. loss: 0.3587, Avg. Uncertainty: 0.1110
# Epoch 3483/3500, Training Loss: 0.2969
# Val. confidence score: 0.7771, Val. loss: 0.3569, Avg. Uncertainty: 0.1199
# Epoch 3484/3500, Training Loss: 0.3023
# Val. confidence score: 0.7765, Val. loss: 0.3545, Avg. Uncertainty: 0.1134
# Epoch 3485/3500, Training Loss: 0.2829
# Val. confidence score: 0.7722, Val. loss: 0.3574, Avg. Uncertainty: 0.1070
# Epoch 3486/3500, Training Loss: 0.2425
# Val. confidence score: 0.7693, Val. loss: 0.3604, Avg. Uncertainty: 0.1001
# Epoch 3487/3500, Training Loss: 0.2577
# Val. confidence score: 0.7682, Val. loss: 0.3665, Avg. Uncertainty: 0.1108
# Epoch 3488/3500, Training Loss: 0.2714
# Val. confidence score: 0.7710, Val. loss: 0.3649, Avg. Uncertainty: 0.1094
# Epoch 3489/3500, Training Loss: 0.2695
# Val. confidence score: 0.7658, Val. loss: 0.3669, Avg. Uncertainty: 0.1120
# Epoch 3490/3500, Training Loss: 0.2811
# Val. confidence score: 0.7650, Val. loss: 0.3637, Avg. Uncertainty: 0.0993
# Epoch 3491/3500, Training Loss: 0.2863
# Val. confidence score: 0.7696, Val. loss: 0.3639, Avg. Uncertainty: 0.1193
# Epoch 3492/3500, Training Loss: 0.2758
# Val. confidence score: 0.7719, Val. loss: 0.3574, Avg. Uncertainty: 0.1098
# Epoch 3493/3500, Training Loss: 0.2415
# Val. confidence score: 0.7719, Val. loss: 0.3574, Avg. Uncertainty: 0.1171
# Epoch 3494/3500, Training Loss: 0.2744
# Val. confidence score: 0.7707, Val. loss: 0.3568, Avg. Uncertainty: 0.1143
# Epoch 3495/3500, Training Loss: 0.2732
# Val. confidence score: 0.7626, Val. loss: 0.3633, Avg. Uncertainty: 0.1064
# Epoch 3496/3500, Training Loss: 0.2668
# Val. confidence score: 0.7716, Val. loss: 0.3659, Avg. Uncertainty: 0.1026
# Epoch 3497/3500, Training Loss: 0.2936
# Val. confidence score: 0.7720, Val. loss: 0.3597, Avg. Uncertainty: 0.1083
# Epoch 3498/3500, Training Loss: 0.2729
# Val. confidence score: 0.7728, Val. loss: 0.3609, Avg. Uncertainty: 0.1132
# Epoch 3499/3500, Training Loss: 0.2697
# Val. confidence score: 0.7676, Val. loss: 0.3676, Avg. Uncertainty: 0.1146
# Epoch 3500/3500, Training Loss: 0.2612
# Val. confidence score: 0.7626, Val. loss: 0.3630, Avg. Uncertainty: 0.1123

# %% [markdown]
# #### Error metrics

# %%
# Plot training history
fig, axes = plt.subplots(3, 1, figsize=(6, 10))
plt.suptitle('Metrics', fontsize=16)

# Losses
axes[0].plot(history['train_loss'], label='Train Loss (MSE + KL Divergence)')
axes[0].plot(history['val_loss'], label='MSE Val. Loss')
axes[0].set_title('Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Confidence Score
axes[1].plot(history['r2'], label='Val. Confidence Score (R^2)')
axes[1].set_title('R^2 Score')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('R^2 Score')
axes[1].legend()

# Uncertainty
axes[2].plot(history['avg_uncertainty'], label='Average Uncertainty')
axes[2].set_title('Average Uncertainty')
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Uncertainty')
axes[2].legend()


plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Get the metrics
model.eval()
y_true = y_test.numpy()
y_pred = []
uncertainties = []

with torch.no_grad():
    for X_batch, Y_batch in test_loader:
        outputs_list = [model(X_batch, mc_dropout=True) for _ in range(1000)] # Increase the number of MC samples for better uncertainty estimation
        outputs_stack = torch.stack(outputs_list)  # Shape: (mc_samples, batch_size, num_classes)
        outputs_mean = outputs_stack.mean(dim=0)  # Average prediction
        outputs_std = outputs_stack.std(dim=0)
        y_pred.extend(outputs_mean.cpu().numpy())
        uncertainties.extend(outputs_std.mean(dim=1).cpu().numpy())

y_pred = np.array(y_pred).reshape(-1, 1)

# Unscale the predictions and true values
y_pred = target_scaler.inverse_transform(y_pred)
y_true = target_scaler.inverse_transform(y_true)

# %% [markdown]
# #### The basic regression metrics

# %%
# MAE
mae = mean_absolute_error(y_true, y_pred)
print(f"Mean Absolute Error (MAE): {mae:.4f}")

# RMSE
rmse = root_mean_squared_error(y_true, y_pred)
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# R^2 Score
r2 = r2_score(y_true, y_pred)
print(f"R^2 Score: {r2:.4f}")

# Average Uncertainty
avg_uncertainty = np.mean(uncertainties)
print(f"Average Uncertainty: {avg_uncertainty:.4f}")

# Explained Variance Score
evs = explained_variance_score(y_true, y_pred)
print(f"Explained Variance Score: {evs:.4f}")

# this model doesn't work that well, but this dataset
# is very noise and similar results were achieved with Classic ML and ANN in previous courses
# Out:
# Mean Absolute Error (MAE): 888207.8750
# Root Mean Squared Error (RMSE): 1205737.1250
# R^2 Score: 0.6614
# Average Uncertainty: 0.1054
# Explained Variance Score: 0.6615

# %%
# plot uncertainty histogram
plt.hist(uncertainties, bins=10, edgecolor='k')
plt.xlabel('Entropy (Uncertainty)')
plt.ylabel('Frequency')
plt.title('Histogram of Uncertainty (Entropy)')
plt.show()

# in optimal case, entropy is stacked on the left side
# with only a small number of uncertainty on the high end

# this particular example is a very bad result, most uncertainty
# is in the high end

# the multi-category version is not usable by default in regression (because we don't have target categories)
# but it might be possible to use binning to inspect in which price ranges the uncertainties happen the most

# %%
# Regression plot
plt.figure(figsize=(10, 6))
plt.scatter(y_true, y_pred, alpha=0.5, color='blue')
plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], 'k--', lw=2)
plt.title('Regression Plot')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.grid()
plt.show()

# %%
# original code from ChatGPT and modified for this project (data and neural network structure)
# Assuming `model` performs MC Dropout and `test_loader` provides data
variances = []  # List to store predictive variance (or standard deviation)

model.eval()
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        # Perform multiple forward passes for MC Dropout
        outputs_list = [model(X_batch, mc_dropout=True) for _ in range(10)]
        outputs_stack = torch.stack(outputs_list)
        
        # Calculate variance across the predictions
        variance = outputs_stack.var(dim=0).cpu().numpy()  # Variance of each prediction
        variances.extend(variance)

# Plot predictive variance (uncertainty)
plt.figure(figsize=(10, 6))
plt.hist(variances, bins=30, alpha=0.7, edgecolor='black')
plt.title('Predictive Variance Distribution')
plt.xlabel('Variance')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# most values should stack close to 0.0... otherwise it usually means noise in the dataset or underfitting
# or difficult data points / overlap

# so improve dataset or model structure / hyperparameters

# %% [markdown]
# ### Use the model in practice (inference)

# %%
df.iloc[542]
# Out:
# price                              1750000
# area                                  3620
# bedrooms                                 2
# bathrooms                                1
# stories                                  1
# mainroad                                 1
# guestroom                                0
# basement                                 0
# hotwaterheating                          0
# airconditioning                          0
# parking                                  0
# prefarea                                 0
# furnishingstatus_semi-furnished      False
# furnishingstatus_unfurnished          True
# Name: 542, dtype: object

# %%
# ORIGINAL CODE FROM CHATGPT AND MODIFIER FOR THE TESTER ROW STRUCTURE FROM EARLIER COURSES

# Define the function for prediction with uncertainty
def predict_with_uncertainty(model, data, feature_scaler, target_scaler, mc_samples=100):
    """
    Predict the price and uncertainty (using MC Dropout) for a new row of data.

    :param model: The trained Bayesian Neural Network model
    :param data: Processed input data for prediction
    :param feature_scaler: Scaler for the input features (used during training)
    :param target_scaler: Scaler for the target variable (price) used during training
    :param mc_samples: Number of Monte Carlo samples to estimate uncertainty
    :return: predicted_price, uncertainty (standard deviation)
    """
    model.eval()  # Set the model to evaluation mode
    predictions = []

    with torch.no_grad():
        for _ in range(mc_samples):
            # Apply MC dropout during inference
            prediction = model(data, mc_dropout=True)  # Get predictions using MC dropout
            predictions.append(prediction.cpu().numpy())

    predictions = np.array(predictions).flatten()  # Flatten predictions to 1D array

    # Compute the mean (predicted value) and the uncertainty (standard deviation)
    predicted_price = predictions.mean()
    uncertainty = predictions.std()

    # Inverse transform the predicted price and uncertainty to original scale
    predicted_price = target_scaler.inverse_transform([[predicted_price]])[0][0]  # Rescale predicted price

    # Uncertainty might need to be scaled back to original scale (if it was scaled during training)
    # uncertainty = uncertainty * target_scaler.scale_[0]  # Scale the uncertainty back to original price scale

    return predicted_price, uncertainty


# Example new row for prediction (using your dataset)
tester_row = {
    "area": 3620,
    "bedrooms": 2,	
    "bathrooms": 1,
    "stories": 1,	
    "mainroad": 1, 
    "guestroom": 0,
    "basement": 0,
    "hotwaterheating": 0,
    "airconditioning": 0,
    "parking": 0,
    "prefarea": 0,
    "furnishingstatus_semi-furnished": 0,	
    "furnishingstatus_unfurnished": 1
}

# Convert the new data to pandas DataFrame
tester_row = pd.DataFrame([tester_row])

# Normalize the input features using feature_scaler (if you scaled them during training)
processed_data = feature_scaler.transform(tester_row.values)

# Convert the scaled data into a tensor
processed_data_tensor = torch.tensor(processed_data, dtype=torch.float32)

# Call the prediction function to get the price and uncertainty
predicted_price, uncertainty = predict_with_uncertainty(model, processed_data_tensor, feature_scaler, target_scaler)

# Output the result
print("\nEstimated price for this house:")
print(f"$ {round(predicted_price, 2)}")
print(f"Uncertainty (Standard Deviation): {round(uncertainty, 2)}")
print("----------------")
# Out:
# Estimated price for this house:
# $ 3331445.96
# Uncertainty (Standard Deviation): 0.029999999329447746
# ----------------
